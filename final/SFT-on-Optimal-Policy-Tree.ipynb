# %% [markdown]
# #  Data Preparation: Converting the Policy Tree to a Dataset

# %%
# %pip install --quiet transformers accelerate bitsandbytes sentence-transformers 
# %pip install -U --quiet outlines  peft  trl
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from huggingface_hub import hf_hub_download
from datasets import load_dataset, Dataset, concatenate_datasets

# --- Load your optimal policy tree from the Hub ---
repo_id = "shahriar7/optimal-20-question-game-policy-tree"
downloaded_file_path = hf_hub_download(
    repo_id=repo_id,
    filename="optimal-20-question-game-policy-tree.json",
    repo_type="dataset"
)

with open(downloaded_file_path, 'r') as f:
    policy_tree = json.load(f)

print("Successfully loaded the policy tree.")

# --- Define System Prompts for both tasks ---
SYSTEM_PROMPT_QUESTION = "You are a 20 Questions player. Your task is to ask the most informative next yes/no question based on the history. The keyword is a simple single-word noun. Start broad and narrow down systematically."
SYSTEM_PROMPT_GUESS = "You are a 20 Questions player. Based on the history, your task is to make the best guess for the secret word. Respond with only the single-word noun."

# --- Modified function to create datasets for both questions and guesses ---
def traverse_and_create_datasets(node, history, question_rows, guess_rows, max_depth, current_depth=0):
    # Stop if the current depth exceeds the maximum depth
    if current_depth >= max_depth:
        return

    # 1. Create data for ASKING A QUESTION (if there's a question at this node)
    if 'question' in node:
        question = node['question']
        
        # Create prompt for asking a question
        prompt_ask = [
            {"role": "system", "content": SYSTEM_PROMPT_QUESTION},
            {"role": "user", "content": f"Game history:\n{''.join(history) if history else 'No history yet.'}\n\nOnly output a single yes/no question."}
        ]
        question_rows.append({"prompt": prompt_ask, "completion": question})

        # 2. Recurse and create data for MAKING A GUESS
        # For the 'yes' branch
        if 'answer_yes' in node and 'guess' in node['answer_yes']:
            guess_yes = node['answer_yes']['guess']
            if guess_yes: # Ensure there is a guess to be made
                new_history_yes = history + [f"Q: {question}\nA: yes\n"]
                prompt_guess_yes = [
                    {"role": "system", "content": SYSTEM_PROMPT_GUESS},
                    {"role": "user", "content": f"Game history:\n{''.join(new_history_yes)}\n\nWhat is your single-word guess?"}
                ]
                guess_rows.append({"prompt": prompt_guess_yes, "completion": guess_yes})
                # Continue traversal
                traverse_and_create_datasets(node['answer_yes'], new_history_yes, question_rows, guess_rows, max_depth, current_depth + 1)
        
        # For the 'no' branch
        if 'answer_no' in node and 'guess' in node['answer_no']:
            guess_no = node['answer_no']['guess']
            if guess_no: # Ensure there is a guess to be made
                new_history_no = history + [f"Q: {question}\nA: no\n"]
                prompt_guess_no = [
                    {"role": "system", "content": SYSTEM_PROMPT_GUESS},
                    {"role": "user", "content": f"Game history:\n{''.join(new_history_no)}\n\nWhat is your single-word guess?"}
                ]
                guess_rows.append({"prompt": prompt_guess_no, "completion": guess_no})
                # Continue traversal
                traverse_and_create_datasets(node['answer_no'], new_history_no, question_rows, guess_rows, max_depth, current_depth + 1)

# --- Start the traversal ---
question_sft_rows = []
guess_sft_rows = []
MAX_TRAVERSAL_DEPTH = 11 # Set your desired depth here
traverse_and_create_datasets(policy_tree, [], question_sft_rows, guess_sft_rows, max_depth=MAX_TRAVERSAL_DEPTH)

# --- Convert lists to Hugging Face Datasets ---
question_dataset = Dataset.from_list(question_sft_rows)
guess_dataset = Dataset.from_list(guess_sft_rows)

print(f"Generated {len(question_dataset)} samples for asking questions.")
print(f"Generated {len(guess_dataset)} samples for making guesses.")

# --- Combine both datasets for multi-task fine-tuning ---
combined_dataset = concatenate_datasets([question_dataset, guess_dataset]).shuffle(seed=42)

print(f"\nTotal combined samples: {len(combined_dataset)}.")

# --- Split the final dataset for training and evaluation ---
dataset_splits = combined_dataset.train_test_split(test_size=0.05, seed=42)
train_ds = dataset_splits["train"]
eval_ds = dataset_splits["test"]

print(f"Final Training samples: {len(train_ds)}, Final Evaluation samples: {len(eval_ds)}")
# Out:
# (…)ptimal-20-question-game-policy-tree.json:   0%|          | 0.00/10.2M [00:00<?, ?B/s]
# Successfully loaded the policy tree.
# Generated 2046 samples for asking questions.
# Generated 4092 samples for making guesses.
#
# Total combined samples: 6138.
# Final Training samples: 5831, Final Evaluation samples: 307

# %% [markdown]
# # Supervised Fine-Tuning (SFT) Setup

# %%
import torch
from peft import LoraConfig
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainerCallback
from trl import SFTTrainer, SFTConfig
from huggingface_hub import login

# --- Login and Configuration ---
login(token="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") # Replace with your Hugging Face token

model_name = "mistralai/Mistral-7B-Instruct-v0.3"

# --- QLoRA Configuration (4-bit quantization) ---
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

# --- LoRA Configuration ---
peft_config = LoraConfig(
    lora_alpha=8,
    lora_dropout=0.05,
    r=16,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj"]# ["q_proj","k_proj","v_proj","o_proj","gate_proj","up_proj","down_proj"] 
)

# --- Load Base Model ---
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True,
)
model.config.use_cache = False

# --- Load Tokenizer ---
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# --- Formatting Function for the Trainer ---
def formatting_prompts_func(example):
    output_texts = []
    for i in range(len(example['prompt'])):
        # Apply the chat template to the prompt messages
        text = tokenizer.apply_chat_template(example['prompt'][i], tokenize=False)
        # Append the completion
        text += example['completion'][i]
        output_texts.append(text)
    return output_texts
# Out:
# 2025-08-26 09:49:33.040030: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756201773.063808     113 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756201773.070810     113 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# --- Corrected data formatting to support completion_only_loss ---

def format_for_sft(dataset):
    """
    Applies the chat template to the 'prompt' column, converting it from a list
    of dictionaries to a single string, which is the format SFTTrainer expects
    when using separate prompt and completion columns.
    """
    def process_batch(batch):
        # Apply the chat template to each list of messages in the 'prompt' column
        formatted_prompts = [
            tokenizer.apply_chat_template(
                prompt_messages, 
                tokenize=False,
                add_generation_prompt=False  # The trainer will add the generation prompt
            ) 
            for prompt_messages in batch['prompt']
        ]
        # Return the batch with the 'prompt' column now as a list of strings
        return {"prompt": formatted_prompts, "completion": batch["completion"]}

    # Apply the processing function to the entire dataset
    return dataset.map(
        process_batch, 
        batched=True,
    )

# Apply the formatting to your train and eval datasets
train_ds = format_for_sft(train_ds)
eval_ds = format_for_sft(eval_ds)
# Out:
# Map:   0%|          | 0/5831 [00:00<?, ? examples/s]
# Map:   0%|          | 0/307 [00:00<?, ? examples/s]

# %% [markdown]
# # Training the Model

# %%
# ignore the warnings in the output.

import wandb
wandb.login(key="b3f46c193418884a60db8ae0148c0eed62f957e6")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
from trl import SFTTrainer, SFTConfig
from peft import LoraConfig, get_peft_model, PeftModel
hub_model_id = "shahriar7/mistral-7b-20q-SFT-finetuned-on-Optimal-Policy-tree"

training_arguments = SFTConfig(
    output_dir="./results",
    num_train_epochs=3,
    per_device_train_batch_size=1,   # starting guess
    auto_find_batch_size=True,       # enable automatic shrinking on OOM
    gradient_accumulation_steps=1,
    optim="paged_adamw_8bit",  
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=True,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="cosine",
    report_to=["tensorboard", "wandb"], 
    eval_strategy="epoch", 
    save_strategy="epoch",      
    save_total_limit=3,          # keep a few recents locally during the run
    logging_strategy="epoch",   
    push_to_hub=True,
    hub_model_id=hub_model_id,
    hub_strategy="checkpoint", # "every_save",
    hub_private_repo=False,
    
    assistant_only_loss=False,  
    completion_only_loss=True,
    
    max_length=512,            
    packing=False,               
    # dataset_text_field="text", # set this if your JSONL column name isn't "text"
    dataloader_num_workers=0,   
    dataset_num_proc=1,         
)

# optional VRAM saver
# model.gradient_checkpointing_enable()

# 2. Create a custom callback to print the loss
class LossMonitorCallback(TrainerCallback):
    def on_log(self, args, state, control, logs=None, **kwargs):
        """
        Event called after logging the evaluation results.
        """
        if logs is not None and "loss" in logs:
            print(f"Step {state.global_step}: Training Loss = {logs['loss']:.4f}")  


wandb.init(
    project="mistral-20q-finetune", 
    config=training_arguments.to_dict(),
)
run_id = wandb.run.id 

if isinstance(model, PeftModel):
    model = model.unload()
    
trainer = SFTTrainer(
    model=model,
    train_dataset=train_ds,
    eval_dataset=eval_ds,
    peft_config=peft_config,
    args=training_arguments,
    processing_class=tokenizer,
    callbacks=[LossMonitorCallback()],
)
# Out:
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250826_095010-doblv0at</code>
# Syncing run <strong><a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/doblv0at' target="_blank">misty-vortex-38</a></strong> to <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune</a>
#  View run at <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/doblv0at' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/doblv0at</a>
# Adding EOS to train dataset:   0%|          | 0/5831 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/5831 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/5831 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/307 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/307 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/307 [00:00<?, ? examples/s]

# %%
trainer.train()

# %%
# Now let's perform SFT:
from pathlib import Path
from transformers.trainer_utils import get_last_checkpoint
from huggingface_hub import snapshot_download

def prepare_resume(output_dir: str, repo_id: str):
    # 1) try local (works during a single Kaggle session)
    local = get_last_checkpoint(output_dir)
    if local:
        return local

    # 2) otherwise pull from the Hub (needs "Internet" ON in Kaggle settings)
    snapshot_download(
        repo_id=repo_id,
        local_dir=output_dir, local_dir_use_symlinks=False,
        allow_patterns=["last-checkpoint/*", "checkpoint-*/*"],  
    )
    last = Path(output_dir) / "last-checkpoint"
    if last.exists():
        return str(last)
    ckpts = sorted(Path(output_dir).glob("checkpoint-*"),
                   key=lambda p: int(p.name.split("-")[-1]))
    return str(ckpts[-1]) if ckpts else None


print("--- Starting from last checkpoing ---")
trainer.args.num_train_epochs=4
resume_path = prepare_resume("./results", hub_model_id)
trainer.train(resume_from_checkpoint=resume_path or None)

wandb.finish()
# Out:
# --- Starting from last checkpoing ---
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:982: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# last-checkpoint/scaler.pt:   0%|          | 0.00/988 [00:00<?, ?B/s]
# last-checkpoint/scheduler.pt:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# last-checkpoint/rng_state.pth:   0%|          | 0.00/14.2k [00:00<?, ?B/s]
# last-checkpoint/optimizer.pt:   0%|          | 0.00/28.0M [00:00<?, ?B/s]
# last-checkpoint/adapter_model.safetensor(…):   0%|          | 0.00/54.6M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# adapter_config.json:   0%|          | 0.00/896 [00:00<?, ?B/s]
# last-checkpoint/tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# last-checkpoint/training_args.bin:   0%|          | 0.00/5.75k [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# trainer_state.json: 0.00B [00:00, ?B/s]
#     <div>
#
#       <progress value='23324' max='23324' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [23324/23324 2:40:47, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3</td>
#       <td>1.311600</td>
#       <td>1.469142</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.807900</td>
#       <td>1.786985</td>
#     </tr>
#   </tbody>
# </table><p>
# Step 17493: Training Loss = 1.3116
# Step 23324: Training Loss = 0.8079
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>▁█</td></tr><tr><td>eval/mean_token_accuracy</td><td>█▁</td></tr><tr><td>eval/num_tokens</td><td>▁█</td></tr><tr><td>eval/runtime</td><td>█▁</td></tr><tr><td>eval/samples_per_second</td><td>▁█</td></tr><tr><td>eval/steps_per_second</td><td>▁█</td></tr><tr><td>train/epoch</td><td>▁▁███</td></tr><tr><td>train/global_step</td><td>▁▁███</td></tr><tr><td>train/grad_norm</td><td>▁█</td></tr><tr><td>train/learning_rate</td><td>█▁</td></tr><tr><td>train/loss</td><td>█▁</td></tr><tr><td>train/mean_token_accuracy</td><td>▁█</td></tr><tr><td>train/num_tokens</td><td>▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>1.78699</td></tr><tr><td>eval/mean_token_accuracy</td><td>0.68895</td></tr><tr><td>eval/num_tokens</td><td>2277480.0</td></tr><tr><td>eval/runtime</td><td>61.3996</td></tr><tr><td>eval/samples_per_second</td><td>5</td></tr><tr><td>eval/steps_per_second</td><td>0.635</td></tr><tr><td>total_flos</td><td>1.9479115115200512e+17</td></tr><tr><td>train/epoch</td><td>4</td></tr><tr><td>train/global_step</td><td>23324</td></tr><tr><td>train/grad_norm</td><td>31.50794</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.8079</td></tr><tr><td>train/mean_token_accuracy</td><td>0.79144</td></tr><tr><td>train/num_tokens</td><td>2277480.0</td></tr><tr><td>train_loss</td><td>0.52988</td></tr><tr><td>train_runtime</td><td>9649.0666</td></tr><tr><td>train_samples_per_second</td><td>2.417</td></tr><tr><td>train_steps_per_second</td><td>2.417</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">misty-vortex-38</strong> at: <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/doblv0at' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/doblv0at</a><br> View project at: <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250826_095010-doblv0at/logs</code>

# %%
# Now let's perform SFT:
from pathlib import Path
from transformers.trainer_utils import get_last_checkpoint
from huggingface_hub import snapshot_download
wandb.init(
    project="mistral-20q-finetune", 
    config=training_arguments.to_dict(),
)
def prepare_resume(output_dir: str, repo_id: str):
    # 1) try local (works during a single Kaggle session)
    local = get_last_checkpoint(output_dir)
    if local:
        return local

    # 2) otherwise pull from the Hub (needs "Internet" ON in Kaggle settings)
    snapshot_download(
        repo_id=repo_id,
        local_dir=output_dir, local_dir_use_symlinks=False,
        allow_patterns=["last-checkpoint/*", "checkpoint-*/*"],  
    )
    last = Path(output_dir) / "last-checkpoint"
    if last.exists():
        return str(last)
    ckpts = sorted(Path(output_dir).glob("checkpoint-*"),
                   key=lambda p: int(p.name.split("-")[-1]))
    return str(ckpts[-1]) if ckpts else None


print("--- Starting from last checkpoing ---")
trainer.args.num_train_epochs=6
resume_path = prepare_resume("./results", hub_model_id)
trainer.train(resume_from_checkpoint=resume_path or None)

wandb.finish()
# Out:
# creating run (1.5s)
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250826_142506-ahc8rfk9</code>
# Syncing run <strong><a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/ahc8rfk9' target="_blank">fancy-smoke-39</a></strong> to <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune</a>
#  View run at <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/ahc8rfk9' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/ahc8rfk9</a>
# --- Starting from last checkpoing ---
#     <div>
#
#       <progress value='29289' max='34986' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [29289/34986 1:22:19 < 1:18:39, 1.21 it/s, Epoch 5.02/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.805000</td>
#       <td>1.834578</td>
#     </tr>
#   </tbody>
# </table><p>
# Step 29155: Training Loss = 0.8050

# %% [markdown]
# # Evaluattion

# %%
# %%writefile test.py

import random
import torch
from typing import List, Dict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from huggingface_hub import login
import logging
logging.getLogger("transformers").setLevel(logging.ERROR)

GAME_WORDS = [
    "cat", "dog", "cow", "horse", "rabbit", "lion", "bear", "shark", "eagle", "ant",
    "apple", "banana", "orange", "carrot", "bread", "cheese", "pizza", "cookie", "egg", "ice-cream",
    "chair", "table", "sofa", "bed", "lamp", "clock", "mirror", "door", "window", "carpet",
    "car", "bicycle", "bus", "train", "airplane", "boat", "rocket", "helmet", "engine", "wheel",
    "pencil", "pen", "book", "paper", "scissors", "ruler", "eraser", "backpack", "laptop", "phone",
    "ball", "doll", "puzzle", "kite", "yo-yo", "drum", "guitar", "camera", "radio", "television",
    "shirt", "pants", "jacket", "hat", "shoes", "gloves", "umbrella", "watch", "glasses",
    "moon", "sun", "star", "cloud", "rain", "snow", "mountain", "river", "ocean", "island",
    "doctor", "teacher", "chef", "farmer", "artist", "pilot", "police", "firefighter", "singer", "dancer",
    "gold", "silver", "iron", "sand", "water", "oil", "soap", "sugar", "salt", "honey"
]

SYSTEM_PROMPT = "You are a precise answering engine. Based on the keyword and question, provide a 'Yes' or 'No' answer."
FEW_SHOT_EXAMPLES = """
[EXAMPLE 1]
Keyword: car
Question: Is it a living thing?
Answer: No
[EXAMPLE 2]
Keyword: water
Question: Is it used for cleaning?
Answer: Yes
[EXAMPLE 3]
Keyword: tree
Question: Is it man-made?
Answer: No
"""

class ValidatorModel:
    
    _model = None
    _tokenizer = None
    _words_dataset = None
    
    def __init__(self):

                
        if ValidatorModel._model is None: # Check if the model has already been loaded (by a previous instantiation)
            print("--- Loading model and tokenizer first time ---")
            login("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", add_to_git_credential=False)
            model_id = "mistralai/Mistral-7B-Instruct-v0.3"

            # Load and assign to the CLASS attributes
            ValidatorModel._tokenizer = AutoTokenizer.from_pretrained(model_id, use_fast=True)
            
            bnb_cfg = BitsAndBytesConfig(load_in_4bit=True,
                                         bnb_4bit_compute_dtype=torch.float16,
                                         bnb_4bit_use_double_quant=True,
                                         bnb_4bit_quant_type="nf4")

            ValidatorModel._model = AutoModelForCausalLM.from_pretrained(
                model_id,
                device_map="auto",
                quantization_config=bnb_cfg,
                trust_remote_code=True,
            ).eval()
            ValidatorModel._words_dataset = GAME_WORDS.copy()
            print("--- Model and tokenizer loaded and cached. ---")
        
        # Assign the cached model/tokenizer to this specific instance
        self.model = ValidatorModel._model
        self.tokenizer = ValidatorModel._tokenizer
        self.words_dataset = ValidatorModel._words_dataset
        
        self.keyword = random.choice(self.words_dataset)
        random.choice(self.words_dataset)
        print(f"\n--- Validator secret word: {self.keyword} ---")
        self.words_dataset.remove(self.keyword) # to not ask same word twice

    def _ask_ai(self, messages: List[Dict], max_new=8, temp=0.01) -> str:
        prompt = self.tokenizer.apply_chat_template(
            messages, tokenize=False, add_generation_prompt=True
        )
        inputs = self.tokenizer(prompt, return_tensors="pt").to(self.model.device)
        out = self.model.generate(
            **inputs,
            max_new_tokens=max_new,
            temperature=temp,
            eos_token_id=self.tokenizer.eos_token_id,
            pad_token_id=self.tokenizer.eos_token_id
        )
        return self.tokenizer.decode(out[0][inputs.input_ids.shape[1]:], skip_special_tokens=True).strip()

    def validate_question(self, question: str) -> str:
        user_content = f"{FEW_SHOT_EXAMPLES}\n[FINAL TASK]\nKeyword: {self.keyword}\nQuestion: {question}\nAnswer:"
        messages = [{"role": "system", "content": SYSTEM_PROMPT}, {"role": "user", "content": user_content}]
        model_ans = self._ask_ai(messages)
        return "yes" if "yes" in model_ans.lower() else "no"

    def validate_guess(self, guess: str) -> str:
        return 'Yes' if guess and self.keyword and guess.lower() == self.keyword.lower() else 'No'
# Out:
# Writing test.py

# %%
# %%writefile evaluate_20Q.py

import argparse
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from test import ValidatorModel
from huggingface_hub import login
import re 

# System prompt for the question-asking model
SYSTEM_PROMPT = "You play 20 Questions. Ask the most informative next yes/no question. The keyword is a simple single-word noun known by most people. Start Broad And divide possibilities in half. Then Narrow Systematically. Do not ask the same question twice"

class Agent:
    """
    An AI agent that uses a single fine-tuned model and disables the LoRA
    adapter to revert to base model behavior for guessing.
    """
    def __init__(self, model_id="shahriar7/mistral-7b-20q-SFT-finetuned-on-Optimal-Policy-tree"):
        print("Loading agent model (base + LoRA adapter)...")
        
        # Authenticate with Hugging Face
        login(token="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", add_to_git_credential=False)
        
        # 4-bit quantization configuration
        bnb_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_compute_dtype=torch.float16,
        )
        
        # Load the single model. Transformers will load the base and apply the adapter.
        self.model = AutoModelForCausalLM.from_pretrained(
            model_id,
            quantization_config=bnb_config,
            torch_dtype=torch.float16,
            device_map="auto",
            trust_remote_code=True,
        )
        self.tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
        self.tokenizer.pad_token = self.tokenizer.eos_token
        print("Agent model loaded successfully.")

    def _generate_response(self, model, messages, temperature=0.7, max_tokens=20):
        """Helper function to generate a response from a specific model."""
        prompt = self.tokenizer.apply_chat_template(
            messages, tokenize=False, add_generation_prompt=True
        )
        inputs = self.tokenizer(prompt, return_tensors="pt").to(model.device)
        
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_tokens,
            do_sample=True,
            temperature=temperature,
            top_p=0.9,
            pad_token_id=self.tokenizer.eos_token_id
        )
        
        response = self.tokenizer.decode(outputs[0][inputs.input_ids.shape[1]:], skip_special_tokens=True)
        return response.strip()

    def ask_question(self, history):
        """Uses the FINE-TUNED model with an improved strategic prompt."""
        history_str = "\n".join(history) if history else "No history yet. Start with a broad question."

        system_prompt = (
            "You are a 20 Questions player. Your task is to ask the most informative next yes/no question based on the history. The keyword is a simple single-word noun. Start broad and narrow down systematically."
        )
        user_prompt = f"Game history:\n{history_str}\n\nOnly output a single yes/no question."
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
        
        # This call is correct, we'll make make_guess match it
        question = self._generate_response(self.model, messages, temperature=0.7, max_tokens=25)
        question = question.split('\n')[0].strip()

        temperature = 0.7
        for retry in range(4):
            if question in history_str:
                print("repeated question, highering temperature")
                temperature += 0.5
                messages[1]["content"]+= "\n\nATTENTION: Your last question was a repeat. You MUST generate a new, unique question."
                question = self._generate_response(self.model, messages, temperature=temperature, max_tokens=25)
                question = question.split('\n')[0].strip()
            else:
                break
            
        return question

    def make_guess(self, history):
        """Temporarily disables the adapter to use the BASE model for guessing."""
        history_str = "\n".join(history)
        
        system_prompt = (
            "You are a 20 Questions player. Based on the history, your task is to make the best guess for the secret word. Respond with only the single-word noun."
        )
        user_prompt = (
            f"Game history:\n{history_str}\n\nWhat is your single-word guess?"
        )
        
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
        
        try:
            self.model.enable_adapters()
            # --- FIX IS HERE: Pass self.model to the function call ---
            guess = self._generate_response(self.model, messages, temperature=0.1, max_tokens=10)
        finally:
            self.model.enable_adapters()

        guess = guess.strip().split()[0]
        guess = re.sub(r"[^a-zA-Z]", "", guess).lower()
        return guess



def play_game(agent, validator):
    """
    Plays a single game of 20 Questions.
    Returns True if the agent wins, False otherwise.
    """
    history = []
    for turn in range(1, 21):
        print(f"\n--- Turn {turn} ---")
        
        # 1. Agent asks a question
        question = agent.ask_question(history)
        print(f"Agent Question: {question}")

        # 2. Validator provides an answer
        answer = validator.validate_question(question)
        print(f"Validator Answer: {answer}")
        
        # 3. Update history with the question and answer
        history.append(f"Q: {question}\nA: {answer}")

        # 4. Agent makes a guess
        guess = agent.make_guess(history)
        print(f"Agent Guess: {guess}")

        # 5. Validator checks the guess
        is_correct_str = validator.validate_guess(guess)
        
        if "yes" in is_correct_str.lower():
            print(f"Agent guessed correctly! The word was '{guess}'.")
            return True
        else:
            print("Agent's guess was incorrect.")
            
    print(f"Agent failed to guess the word in 20 turns. The word was '{validator.keyword}'.")
    return False

def run_evaluation(num_games):
    """
    Runs the full evaluation for a specified number of games.
    """
    agent = Agent()
    wins = 0

    for i in range(num_games):
        print(f"\n====================\n  Starting Game {i + 1}/{num_games}\n====================")
        # A new validator is created for each game to get a new random word [cite: 78]
        validator = ValidatorModel() 
        if play_game(agent, validator):
            wins += 1
    
    print("\n--- Evaluation Finished ---")
    print(f"Final Score: {wins} / {num_games} wins ({wins/num_games:.2%})")


if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Evaluate a 20 Questions agent.")
    login("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", add_to_git_credential=False)
    parser.add_argument(
        "-N",
        "--num_games",
        type=int,
        required=True,
        help="The number of games to play for the evaluation."
    )
    args = parser.parse_args()
    
    run_evaluation(args.num_games)
# Out:
# Overwriting evaluate_20Q.py

# %%
# !python evaluate_20Q.py -N 10
# Out:
# Loading agent model (base + LoRA adapter)...
# 2025-08-26 18:20:12.321231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756232412.347693     239 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756232412.357011     239 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:16<00:00,  5.48s/it]
# Agent model loaded successfully.
#
# ====================
#   Starting Game 1/10
# ====================
# --- Loading model and tokenizer first time ---
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:15<00:00,  5.06s/it]
# --- Model and tokenizer loaded and cached. ---
#
# --- Validator secret word: eagle ---
#
# --- Turn 1 ---
# Agent Question: Is it used for entertainment?
# Validator Answer: no
# Agent Guess: search
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it a location or place?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it a word game?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it a service?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it an abstract concept?
# Validator Answer: no
# Agent Guess: back
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it a biological term?
# Validator Answer: yes
# Agent Guess: mouth
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Do people use it every day?
# Validator Answer: no
# Agent Guess: tits
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is it perishable?
# Validator Answer: no
# Agent Guess: vaccine
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is it related to culture?
# Validator Answer: no
# Agent Guess: wing
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is it used for medical treatment?
# Validator Answer: no
# Agent Guess: wing
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is it a body part?
# Validator Answer: no
# Agent Guess: plague
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is it related to time?
# Validator Answer: no
# Agent Guess: venom
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Did it exist 100 years ago?
# Validator Answer: yes
# Agent Guess: pregnancy
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is it a plant?
# Validator Answer: no
# Agent Guess: wrinkle
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is it a material or substance?
# Validator Answer: no
# Agent Guess: pregnancy
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is it animate?
# Validator Answer: yes
# Agent Guess: soldier
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is it a predator?
# Validator Answer: yes
# Agent Guess: tiger
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is it larger than a microwave?
# Validator Answer: yes
# Agent Guess: wolf
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is it an aquatic animal ?
# Validator Answer: no
# Agent Guess: tiger
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is it a mammal?
# Validator Answer: no
# Agent Guess: hawk
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'eagle'.
#
# ====================
#   Starting Game 2/10
# ====================
#
# --- Validator secret word: sugar ---
#
# --- Turn 1 ---
# Agent Question: Is it commonly found in an office?
# Validator Answer: no
# Agent Guess: search
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it a tool?
# Validator Answer: no
# Agent Guess: year
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it used for entertainment?
# Validator Answer: no
# Agent Guess: year
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it a word game?
# Validator Answer: no
# Agent Guess: year
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it used for education or learning?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it related to culture?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is it reusable?
# Validator Answer: no
# Agent Guess: buy
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is it solid?
# Validator Answer: yes
# Agent Guess: part
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is it a body part?
# Validator Answer: no
# Agent Guess: blackhole
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is it a material or substance?
# Validator Answer: yes
# Agent Guess: black
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is it a chemical?
# Validator Answer: yes
# Agent Guess: caffeine
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is it used for medical treatment?
# Validator Answer: no
# Agent Guess: dye
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is it used for cleaning?
# Validator Answer: no
# Agent Guess: coal
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is it commonly found in a factory?
# Validator Answer: yes
# Agent Guess: black
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is it used for heating?
# Validator Answer: no
# Agent Guess: slag
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is it a metal?
# Validator Answer: no
# Agent Guess: black
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is it a product of nature?
# Validator Answer: yes
# Agent Guess: acrylic
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is it used for lighting?
# Validator Answer: no
# Agent Guess: acid
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is it used for carrying things?
# Validator Answer: no
# Agent Guess: acid
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is it commonly found at school?
# Validator Answer: no
# Agent Guess: catalyst
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'sugar'.
#
# ====================
#   Starting Game 3/10
# ====================
#
# --- Validator secret word: shoes ---
#
# --- Turn 1 ---
# Agent Question: Is it a material or substance?
# Validator Answer: no
# Agent Guess: visit
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it used for communication?
# Validator Answer: no
# Agent Guess: day
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it used for education or learning?
# Validator Answer: no
# Agent Guess: order
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it a location or place?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it a word game?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it commonly found in an office?
# Validator Answer: no
# Agent Guess: month
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is it related to culture?
# Validator Answer: yes
# Agent Guess: privacy
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is it reusable?
# Validator Answer: yes
# Agent Guess: tradition
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is it a service?
# Validator Answer: no
# Agent Guess: recipe
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is it used for entertainment?
# Validator Answer: no
# Agent Guess: recipe
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is it a piece of clothing?
# Validator Answer: yes
# Agent Guess: veil
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is it commonly found in a hospital?
# Validator Answer: no
# Agent Guess: headband
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is it a body part?
# Validator Answer: no
# Agent Guess: scarf
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# repeated question, highering temperature
# Agent Question: Is it used for carrying things?
# Validator Answer: no
# Agent Guess: collar
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is it used for protection or safety?
# Validator Answer: yes
# Agent Guess: collar
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# repeated question, highering temperature
# Agent Question: Is it commonly found in a factory?
# Validator Answer: no
# Agent Guess: collar
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is it a piece of furniture?
# Validator Answer: no
# Agent Guess: sleeve
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is it made of fabric or cloth?
# Validator Answer: yes
# Agent Guess: scarf
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is it a product of nature?
# Validator Answer: no
# Agent Guess: scarf
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Does it have a lid?
# Validator Answer: no
# Agent Guess: collar
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'shoes'.
#
# ====================
#   Starting Game 4/10
# ====================
#
# --- Validator secret word: teacher ---
#
# --- Turn 1 ---
# Agent Question: Is it a material or substance?
# Validator Answer: no
# Agent Guess: visit
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it an abstract concept?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it a location or place?
# Validator Answer: no
# Agent Guess: back
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it reusable?
# Validator Answer: no
# Agent Guess: birthday
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it a biological term?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it related to time?
# Validator Answer: no
# Agent Guess: sister
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is it a word game?
# Validator Answer: no
# Agent Guess: cost
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is it a service?
# Validator Answer: yes
# Agent Guess: pharmacy
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Do people use it every day?
# Validator Answer: yes
# Agent Guess: pharmacy
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is it used for education or learning?
# Validator Answer: yes
# Agent Guess: teacher
# Agent guessed correctly! The word was 'teacher'.
#
# ====================
#   Starting Game 5/10
# ====================
#
# --- Validator secret word: car ---
#
# --- Turn 1 ---
# Agent Question: Is it used for entertainment?
# Validator Answer: no
# Agent Guess: search
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it used for education or learning?
# Validator Answer: no
# Agent Guess: order
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it related to time?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it a word game?
# Validator Answer: no
# Agent Guess: contact
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it an abstract concept?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it used for communication?
# Validator Answer: no
# Agent Guess: sale
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is it a biological term?
# Validator Answer: no
# Agent Guess: sale
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is it a location or place?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is it reusable?
# Validator Answer: yes
# Agent Guess: fix
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is it used for storage?
# Validator Answer: no
# Agent Guess: parts
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is it used for construction?
# Validator Answer: no
# Agent Guess: refill
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is it used for protection or safety?
# Validator Answer: no
# Agent Guess: refill
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is it a service?
# Validator Answer: no
# Agent Guess: buy
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is it used for cleaning?
# Validator Answer: no
# Agent Guess: buy
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is it a product of nature?
# Validator Answer: no
# Agent Guess: adjust
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is it commonly found in an office?
# Validator Answer: no
# Agent Guess: cocoon
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is it used for carrying things?
# Validator Answer: yes
# Agent Guess: basket
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is it a tool?
# Validator Answer: yes
# Agent Guess: lever
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is it used for heating?
# Validator Answer: no
# Agent Guess: paddle
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is it used for cutting?
# Validator Answer: no
# Agent Guess: pump
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'car'.
#
# ====================
#   Starting Game 6/10
# ====================
#
# --- Validator secret word: sofa ---
#
# --- Turn 1 ---
# Agent Question: Is it commonly found in an office?
# Validator Answer: yes
# Agent Guess: email
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it a tool?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it used for storage?
# Validator Answer: no
# Agent Guess: mail
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it a service?
# Validator Answer: no
# Agent Guess: page
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it used for education or learning?
# Validator Answer: no
# Agent Guess: bill
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it a material or substance?
# Validator Answer: no
# Agent Guess: hour
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is it used for communication?
# Validator Answer: no
# Agent Guess: salary
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is it used for construction?
# Validator Answer: no
# Agent Guess: salary
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is it used for protection or safety?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is it a location or place?
# Validator Answer: no
# Agent Guess: salary
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is it a stationery item?
# Validator Answer: no
# Agent Guess: salary
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is it used for lighting?
# Validator Answer: no
# Agent Guess: salary
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is it related to culture?
# Validator Answer: no
# Agent Guess: bill
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is it used for transportation?
# Validator Answer: no
# Agent Guess: configuration
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# repeated question, highering temperature
# Agent Question: Is it programmable?
# Validator Answer: no
# Agent Guess: configuration
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is it a piece of clothing?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is it a building or structure?
# Validator Answer: no
# Agent Guess: bill
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is it a single letter?
# Validator Answer: no
# Agent Guess: configuration
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is it commonly found at school?
# Validator Answer: no
# Agent Guess: bill
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# repeated question, highering temperature
# Agent Question: Is it solid?
# Validator Answer: yes
# Agent Guess: brown
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'sofa'.
#
# ====================
#   Starting Game 7/10
# ====================
#
# --- Validator secret word: cloud ---
#
# --- Turn 1 ---
# Agent Question: Is it used for entertainment?
# Validator Answer: no
# Agent Guess: search
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it a location or place?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it related to culture?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it a word game?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it an abstract concept?
# Validator Answer: yes
# Agent Guess: power
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it a biological term?
# Validator Answer: no
# Agent Guess: private
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is it related to time?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Do people use it every day?
# Validator Answer: no
# Agent Guess: bad
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is it used for education or learning?
# Validator Answer: no
# Agent Guess: negative
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is it a living thing?
# Validator Answer: no
# Agent Guess: bad
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is it stationary?
# Validator Answer: yes
# Agent Guess: shadow
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is it solid?
# Validator Answer: no
# Agent Guess: shadow
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# repeated question, highering temperature
# Agent Question: Is it used for storage?
# Validator Answer: no
# Agent Guess: shadow
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# repeated question, highering temperature
# Agent Question: Is it a single letter?
# Validator Answer: no
# Agent Guess: shadow
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is it used for measuring?
# Validator Answer: no
# Agent Guess: shadow
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# repeated question, highering temperature
# Agent Question: Is it a tool?
# Validator Answer: no
# Agent Guess: shadow
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is it used for cooling?
# Validator Answer: no
# Agent Guess: shadow
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is it used for carrying things?
# Validator Answer: no
# Agent Guess: shadow
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is it a single syllable?
# Validator Answer: no
# Agent Guess: shadow
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is it a service?
# Validator Answer: no
# Agent Guess: shadow
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'cloud'.
#
# ====================
#   Starting Game 8/10
# ====================
#
# --- Validator secret word: lion ---
#
# --- Turn 1 ---
# Agent Question: Is it a word game?
# Validator Answer: no
# Agent Guess: contact
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it a location or place?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it reusable?
# Validator Answer: no
# Agent Guess: year
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it solid?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it a service?
# Validator Answer: no
# Agent Guess: browse
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it used for entertainment?
# Validator Answer: yes
# Agent Guess: forum
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is it used for education or learning?
# Validator Answer: no
# Agent Guess: party
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is it used for sports or exercise?
# Validator Answer: no
# Agent Guess: glitter
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is it commonly found at school?
# Validator Answer: no
# Agent Guess: glitter
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Does it require training or skill to use properly?
# Validator Answer: no
# Agent Guess: boo
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is it a TV show?
# Validator Answer: no
# Agent Guess: flight
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# repeated question, highering temperature
# Agent Question: Is it a toy or game?
# Validator Answer: no
# Agent Guess: glitter
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# repeated question, highering temperature
# Agent Question: Does it make noise
# Validator Answer: yes
# Agent Guess: drum
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is it used for construction?
# Validator Answer: no
# Agent Guess: fireworks
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is it a single letter?
# Validator Answer: no
# Agent Guess: orchestra
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is it a biological term?
# Validator Answer: yes
# Agent Guess: yawn
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is it fragile?
# Validator Answer: no
# Agent Guess: growl
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is it used for protection or safety?
# Validator Answer: yes
# Agent Guess: jaw
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is it found indoors?
# Validator Answer: no
# Agent Guess: beak
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is it a body part?
# Validator Answer: no
# Agent Guess: predator
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'lion'.
#
# ====================
#   Starting Game 9/10
# ====================
#
# --- Validator secret word: firefighter ---
#
# --- Turn 1 ---
# Agent Question: Is it used for entertainment?
# Validator Answer: no
# Agent Guess: search
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it used for education or learning?
# Validator Answer: no
# Agent Guess: order
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it related to time?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it an abstract concept?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it a biological term?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it a location or place?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is it a material or substance?
# Validator Answer: no
# Agent Guess: sister
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is it a word game?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is it related to culture?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is it a service?
# Validator Answer: no
# Agent Guess: gravity
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Did it exist 100 years ago?
# Validator Answer: yes
# Agent Guess: back
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is it reusable?
# Validator Answer: no
# Agent Guess: saturday
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is it a body part?
# Validator Answer: no
# Agent Guess: soldier
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is it solid?
# Validator Answer: no
# Agent Guess: saturday
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# repeated question, highering temperature
# Agent Question: Is it used for measuring?
# Validator Answer: no
# Agent Guess: soldier
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is it used for medical treatment?
# Validator Answer: no
# Agent Guess: saturday
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# repeated question, highering temperature
# Agent Question: Is it related to law?
# Validator Answer: no
# Agent Guess: saturday
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# repeated question, highering temperature
# Agent Question: Do people use it every day?
# Validator Answer: yes
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is it a tool?
# Validator Answer: no
# Agent Guess: sale
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is it used for protection or safety?
# Validator Answer: yes
# Agent Guess: safety
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'firefighter'.
#
# ====================
#   Starting Game 10/10
# ====================
#
# --- Validator secret word: scissors ---
#
# --- Turn 1 ---
# Agent Question: Is it related to culture?
# Validator Answer: no
# Agent Guess: search
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it a location or place?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it a word game?
# Validator Answer: no
# Agent Guess: price
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it a living thing?
# Validator Answer: no
# Agent Guess: year
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it a material or substance?
# Validator Answer: no
# Agent Guess: year
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it an abstract concept?
# Validator Answer: no
# Agent Guess: sister
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is it related to time?
# Validator Answer: no
# Agent Guess: sales
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is it reusable?
# Validator Answer: yes
# Agent Guess: fix
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is it a service?
# Validator Answer: no
# Agent Guess: wheel
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is it used for education or learning?
# Validator Answer: no
# Agent Guess: sail
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is it a piece of clothing?
# Validator Answer: no
# Agent Guess: refill
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is it used for carrying things?
# Validator Answer: no
# Agent Guess: battery
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is it used for heating?
# Validator Answer: no
# Agent Guess: battery
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is it used for cooling?
# Validator Answer: no
# Agent Guess: paddle
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is it a building or structure?
# Validator Answer: no
# Agent Guess: battery
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is it used for storage?
# Validator Answer: no
# Agent Guess: turn
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is it used for protection or safety?
# Validator Answer: no
# Agent Guess: rental
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is it a tool?
# Validator Answer: yes
# Agent Guess: remote
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is it used for cutting?
# Validator Answer: yes
# Agent Guess: blade
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is it a weapon?
# Validator Answer: no
# Agent Guess: cane
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'scissors'.
#
# --- Evaluation Finished ---
# Final Score: 1 / 10 wins (10.00%)
