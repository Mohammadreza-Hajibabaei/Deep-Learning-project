# %%
# %pip install --quiet transformers accelerate bitsandbytes sentence-transformers #faiss-cpu
# %pip install faiss-gpu-cu12  --quiet
# %pip install -U --quiet outlines  peft  trl
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 28.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 52.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 50.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 28.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.2 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.4 MB/s eta 0:00:00:00:0100:01
# Note: you may need to restart the kernel to use updated packages.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 MB 37.1 MB/s eta 0:00:00:00:0100:01
# Note: you may need to restart the kernel to use updated packages.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.3/94.3 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 39.6 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 504.9/504.9 kB 31.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.9/511.9 kB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 94.1 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 37.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 912.7/912.7 kB 51.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 16.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import random
import os
import requests
import pandas as pd
from datasets import load_dataset
import torch, gc, os, re
from huggingface_hub import login
from transformers import AutoTokenizer
import numpy as np

# %% [markdown]
# # Dataset Preperation

# %%
include_guess = False
filter_flag = True

def parse_q20llm_csv(dataframe):
    games = []
    current_game = None
    for _, row in dataframe.sort_index().iterrows():
        turn_number = int(row['turn'])
        
        if turn_number == 1:
            if current_game:
                games.append(current_game)
            
            current_game = {
                "lines": [],
                "word": [row['keyword']], # Use 'keyword' column
                "correct": False  # Default to False, will be updated later
            }

        # If we are in the middle of a game, add the current line
        if current_game:
            current_game['lines'].append(f"{row['question']} {row['answer']}")

    # After the loop finishes, make sure to add the very last game
    if current_game:
        games.append(current_game)
    for game in games:
        if len(game['lines']) <= 20:
            game['correct'] = True
            
    return games

def load_all_samples(
    berkeley_filepath="rl-llm-bench-dataset.json",
    huggingface_cached_filepath="EDA_twenty_questions_dataset.json",
    correct_percent_for_berkeley=0.85
):
    final_samples = []

    # --- 1. Load and Balance the Berkeley dataset ---
    berkeley_data = []
    if os.path.exists(berkeley_filepath):
        print(f"Loading Berkeley dataset from local file: '{berkeley_filepath}'")
        with open(berkeley_filepath, 'r') as f:
            berkeley_data = json.load(f)
    else:
        # Download if not found
        print(f"Local Berkeley file not found. Downloading from URL...")
        url = "https://rail.eecs.berkeley.edu/datasets/rl-llm-bench-dataset/twenty-questions/train.json"
        try:
            response = requests.get(url)
            response.raise_for_status()
            berkeley_data = response.json()
            with open(berkeley_filepath, 'w') as f:
                json.dump(berkeley_data, f)
            print(f"Successfully downloaded and saved Berkeley data to '{berkeley_filepath}'.")
        except requests.exceptions.RequestException as e:
            print(f"Error downloading Berkeley data: {e}")

    if berkeley_data:
        correct_samples = [s for s in berkeley_data if s.get('correct')]
        incorrect_samples = [s for s in berkeley_data if not s.get('correct')]
        
        num_correct_to_keep = int(len(correct_samples) * correct_percent_for_berkeley)
        num_incorrect_to_keep = int(len(incorrect_samples) * (1 - correct_percent_for_berkeley))

        # Ensure we don't request more samples than available
        num_correct_to_keep = min(num_correct_to_keep, len(correct_samples))
        num_incorrect_to_keep = min(num_incorrect_to_keep, len(incorrect_samples))
        
        balanced_berkeley = random.sample(correct_samples, num_correct_to_keep) + random.sample(incorrect_samples, num_incorrect_to_keep)
        random.shuffle(balanced_berkeley)
        final_samples.extend(balanced_berkeley)
        print(f"Added {len(balanced_berkeley)} balanced samples from Berkeley dataset.")

    # --- 2. Load the Hugging Face Q20LLM dataset ---
    hf_data = []
    if os.path.exists(huggingface_cached_filepath):
        print(f"Loading Hugging Face dataset from local cache: '{huggingface_cached_filepath}'")
        with open(huggingface_cached_filepath, 'r') as f:
            hf_data = json.load(f)
    else:
        print(f"Local Hugging Face cache not found. Loading from 'cvmistralparis/Q20LLM' and parsing...")
        try:
            # CORRECTED: Use the 'games' configuration as requested
            ds = load_dataset("cvmistralparis/Q20LLM", "games", split='train')
            df = ds.to_pandas()
            
            # Use the correct parser for the flat CSV-like structure
            hf_data = parse_q20llm_csv(df)
            
            with open(huggingface_cached_filepath, 'w') as f:
                json.dump(hf_data, f)
            print(f"Successfully parsed and saved Hugging Face data to '{huggingface_cached_filepath}'.")
        except Exception as e:
            print(f"Could not load or parse Hugging Face dataset. Error: {e}")
    
    final_samples.extend(hf_data)
    print(f"Added {len(hf_data)} samples from Hugging Face dataset.")
    print(f"\nTotal samples loaded: {len(final_samples)}")
    return final_samples



# --- Example Usage ---
# Step 1: Load all the data. This will download/parse/cache files as needed and balance the Berkeley data.
raw_game_data = load_all_samples(correct_percent_for_berkeley=0.85)


def generate_guess_for_turn(history, model, tokenizer):
    """
    Uses the provided LLM to generate a guess based on the game history.
    """
    history_str = "\n".join([f"Q: {turn['q']} A: {turn['a']}" for turn in history])
    prompt = f"""You are an expert 20 Questions player. Based on the following history, make your best guess for the secret word. Respond with only the word.
    History:
    {history_str}"""
    
    messages = [{"role": "user", "content": prompt}]

    # CORRECTED: Properly format the prompt and get the attention mask
    prompt_str = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    inputs = tokenizer(prompt_str, return_tensors="pt").to(model.device)
    
    # Pass the unpacked inputs dictionary and the pad_token_id
    do_sample = True
    outputs = model.generate(
        **inputs,
        max_new_tokens=5,
        do_sample=do_sample,
        temperature=0.7,
        pad_token_id=tokenizer.pad_token_id,  eos_token_id=tokenizer.eos_token_id
    )
    
    # Decode only the newly generated tokens
    response = tokenizer.decode(outputs[0][inputs.input_ids.shape[-1]:], skip_special_tokens=True)
    
    guess = response.strip().lower()
    return guess.split(" ")[0].replace(".", "")

def create_20q_dataset(
    all_samples,
    output_filepath,
    include_guess=True,
    filter_flag=True,
    word_list_filepath="words.txt"
):
    """
    Processes a list of game samples according to the specified flags.
    """
    # --- 1. Filter by word list if the flag is set ---
    if filter_flag:
        try:
            with open(word_list_filepath, 'r') as f:
                valid_words = {line.strip().lower() for line in f}
            
            all_samples = [
                sample for sample in all_samples
                if sample['word'][0].lower() in valid_words
            ]
            print(f"Filtered dataset to {len(all_samples)} samples based on '{word_list_filepath}'.")
        except FileNotFoundError:
            print(f"Warning: Word list not found at {word_list_filepath}. Skipping filter.")

    # --- 2. Process samples to create the final dataset ---
    processed_dataset = []
    for i, sample in enumerate(all_samples):
        secret_word = sample['word'][0]
        gameplay = []
        history_for_guess = []

        for line in sample['lines']:
            parts = line.split("? ")
            if len(parts) < 2: continue
            question = parts[0] + "?"
            answer = parts[1].strip().lower()

            turn_data = {"question": question, "answer": answer}
            history_for_guess.append({"q": question, "a": answer})

            if include_guess:
                guess = generate_guess_for_turn(history_for_guess, model, tokenizer)
                turn_data['guess'] = guess
                turn_data['correct_guess'] = "yes" if guess.lower() == secret_word.lower() else "no"
            
            gameplay.append(turn_data)

        processed_dataset.append({"word": secret_word, "gameplay": gameplay})
        # if i%10==0:
        #     print(f"Processing sample {i+1}/{len(all_samples)}...")
        #     print(secret_word, gameplay)
    # --- 3. Save the new dataset ---
    with open(output_filepath, 'w') as f:
        json.dump(processed_dataset, f, indent=2)
    
    print(f"\nSuccessfully created and saved the new dataset to '{output_filepath}'.")



# Step 2: Process the loaded data to create the final SFT dataset.
create_20q_dataset(
    all_samples=raw_game_data,
    output_filepath="sft_dataset_combined.json",
    include_guess=include_guess,
    filter_flag=filter_flag,
    word_list_filepath="/kaggle/input/words-list/200_common_nouns.txt"
)
# Out:
# Local Berkeley file not found. Downloading from URL...
# Successfully downloaded and saved Berkeley data to 'rl-llm-bench-dataset.json'.
# Added 36676 balanced samples from Berkeley dataset.
# Local Hugging Face cache not found. Loading from 'cvmistralparis/Q20LLM' and parsing...
# README.md: 0.00B [00:00, ?B/s]
# train.csv: 0.00B [00:00, ?B/s]
# test.csv: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/70950 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5294 [00:00<?, ? examples/s]
# Successfully parsed and saved Hugging Face data to 'EDA_twenty_questions_dataset.json'.
# Added 5566 samples from Hugging Face dataset.
#
# Total samples loaded: 42242
# Filtered dataset to 18547 samples based on '/kaggle/input/words-list/200_common_nouns.txt'.
#
# Successfully created and saved the new dataset to 'sft_dataset_combined.json'.

# %% [markdown]
# # Supervised Fine-tuning

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, get_peft_model, PeftModel
from trl import apply_chat_template
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    TrainerCallback  # 1. Import TrainerCallback
)
from trl import SFTTrainer
from huggingface_hub import login

login(token="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")


# 1. Model and Tokenizer Setup
model_name = "mistralai/Mistral-7B-Instruct-v0.3"
dataset_name = "formatted_20q_dataset.jsonl"
hub_model_id = "shahriar7/mistral-7b-20q-finetuned"

# 2. QLoRA Configuration (4-bit quantization)
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

# 3. LoRA Configuration
peft_config = LoraConfig(
    lora_alpha=8,
    lora_dropout=0.05,
    r=16,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj"]
)
# target_modules=["q_proj","k_proj","v_proj","o_proj","gate_proj","up_proj","down_proj"],
#
# 4. Load Base Model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True,
)
model.config.use_cache = False
# model.gradient_checkpointing_enable()

# 5. Load Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# 2025-08-22 13:04:27.730420: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755867868.066783     110 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755867868.167617     110 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json:   0%|          | 0.00/601 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.55G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/141k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
SYSTEM = "You play 20 Questions. Ask the most informative next yes/no question. The keyword is a simple single-word noun known by most people. Start Broad And divide possibilities in half. Then Narrow Systematically. Do not ask the same question twice"

def to_prompt_completion_rows(game):
    rows, hist = [], []
    for turn in game.get("gameplay", []):
        q, a = turn.get("question"), turn.get("answer")
        if q:
            prompt_msgs = [
                {"role":"system","content":SYSTEM},
                {"role":"user","content":"Game history:\n" + ("\n".join(hist) if hist else "No history yet.")
                                 + "\n\nOnly output a single yes/no question."}
            ]
            # Render ONLY the prompt to the model's chat template as a STRING
            prompt_str = tokenizer.apply_chat_template(
                prompt_msgs, tokenize=False, add_generation_prompt=False
            )
            rows.append({"prompt": prompt_str, "completion": q.strip()})
        if q and a:
            hist.append(f"Q: {q}\nA: {a.strip()}")
    return rows

def process_dataset(in_path, out_path):
    data = json.load(open(in_path, "r", encoding="utf-8"))
    with open(out_path, "w", encoding="utf-8") as f:
        for game in data:
            for row in to_prompt_completion_rows(game):
                f.write(json.dumps(row, ensure_ascii=False) + "\n")

process_dataset("sft_dataset_combined.json", "formatted_20q_dataset.jsonl")
raw_ds = load_dataset("json", data_files=dataset_name, split="train")

# Split the structured dataset into training and evaluation sets
splits = raw_ds.train_test_split(test_size=0.03, seed=42) # Using a 5% eval split
train_ds = splits["train"]
eval_ds = splits["test"]
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
eos = tokenizer.eos_token or ""

# ---- (1) Full sequence length: prompt + completion + EOS ----
def _batch_full_len(batch):
    texts = [
        p + c + ("" if c.endswith(eos) else eos)
        for p, c in zip(batch["prompt"], batch["completion"])
    ]
    enc = tokenizer(texts, add_special_tokens=False, return_length=True)
    return {"full_len": enc["length"]}

full_stats = train_ds.map(_batch_full_len, batched=True, remove_columns=[])
full_arr = np.array(full_stats["full_len"])
p50_full = int(np.quantile(full_arr, 0.50))
p95_full = int(np.quantile(full_arr, 0.95))
p99_full = int(np.quantile(full_arr, 0.99))
max_full = int(full_arr.max())
print(f"FULL  tokens — p50:{p50_full}  p95:{p95_full}  p99:{p99_full}  max:{max_full}")

# ---- (2) Optional: prompt-only and completion-only diagnostics ----
def _batch_parts_len(batch):
    prompts = batch["prompt"]
    completions = [c + ("" if c.endswith(eos) else eos) for c in batch["completion"]]

    enc_p = tokenizer(prompts, add_special_tokens=False, return_length=True)
    enc_c = tokenizer(completions, add_special_tokens=False, return_length=True)

    return {"prompt_len": enc_p["length"], "completion_len": enc_c["length"]}

parts_stats = train_ds.map(_batch_parts_len, batched=True, remove_columns=[])
p_arr = np.array(parts_stats["prompt_len"])
c_arr = np.array(parts_stats["completion_len"])

print(f"PROMPT    p50:{int(np.quantile(p_arr,0.50))}  p95:{int(np.quantile(p_arr,0.95))}  p99:{int(np.quantile(p_arr,0.99))}  max:{int(p_arr.max())}")
print(f"COMPLETION p50:{int(np.quantile(c_arr,0.50))}  p95:{int(np.quantile(c_arr,0.95))}  p99:{int(np.quantile(c_arr,0.99))}  max:{int(c_arr.max())}")

# ---- (3) Pick SFT max_length from p99 (or a value you prefer), bounded by model context ----
model_max = getattr(tokenizer, "model_max_length", None) or 10**9
suggested_max_length = min(p99_full, model_max)
print("Suggested SFT max_length:", suggested_max_length)
# Out:
# Map:   0%|          | 0/240561 [00:00<?, ? examples/s]
# FULL  tokens — p50:174  p95:350  p99:396  max:560
# Map:   0%|          | 0/240561 [00:00<?, ? examples/s]
# PROMPT    p50:165  p95:340  p99:384  max:550
# COMPLETION p50:8  p95:12  p99:16  max:45
# Suggested SFT max_length: 396

# %%
# ignore the warnings in the output.

import wandb
wandb.login(key="b3f46c193418884a60db8ae0148c0eed62f957e6")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: shahriarbasiri (shahriarbasiri-sharif-university-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
from trl import SFTTrainer, SFTConfig

training_arguments = SFTConfig(
    output_dir="./results",
    num_train_epochs=3,
    per_device_train_batch_size=2,   # starting guess
    auto_find_batch_size=True,       # enable automatic shrinking on OOM
    gradient_accumulation_steps=4,
    optim="paged_adamw_8bit",  
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=True,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=5000,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="cosine",
    report_to=["tensorboard", "wandb"], 
    eval_strategy="steps", eval_steps=1000,
    save_strategy="steps",       save_steps=1000,
    save_total_limit=3,          # keep a few recents locally during the run
    logging_strategy="steps",    logging_steps=200,
    push_to_hub=True,
    hub_model_id=hub_model_id,
    hub_strategy="checkpoint", # "every_save",
    hub_private_repo=False,
    
    # assistant_only_loss=True,  
    completion_only_loss=True,
    
    max_length=512,            
    packing=False,               
    # dataset_text_field="text", # set this if your JSONL column name isn't "text"
    dataloader_num_workers=2,   
    dataset_num_proc=2,         
)

# optional VRAM saver
# model.gradient_checkpointing_enable()

# 2. Create a custom callback to print the loss
class LossMonitorCallback(TrainerCallback):
    def on_log(self, args, state, control, logs=None, **kwargs):
        """
        Event called after logging the evaluation results.
        """
        if logs is not None and "loss" in logs:
            print(f"Step {state.global_step}: Training Loss = {logs['loss']:.4f}")  


wandb.init(
    project="mistral-20q-finetune", 
    config=training_arguments.to_dict(),
)
run_id = wandb.run.id 

if isinstance(model, PeftModel):
    model = model.unload()
    
trainer = SFTTrainer(
    model=model,
    train_dataset=train_ds,
    eval_dataset=eval_ds,
    peft_config=peft_config,
    args=training_arguments,
    processing_class=tokenizer,
    callbacks=[LossMonitorCallback()],
)
# Out:
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250822_134211-f8tsl6x3</code>
# Syncing run <strong><a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/f8tsl6x3' target="_blank">lunar-sun-12</a></strong> to <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune</a>
#  View run at <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/f8tsl6x3' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/f8tsl6x3</a>
# Adding EOS to train dataset (num_proc=2):   0%|          | 0/240561 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=2):   0%|          | 0/240561 [00:00<?, ? examples/s]
# Truncating train dataset (num_proc=2):   0%|          | 0/240561 [00:00<?, ? examples/s]
# Adding EOS to eval dataset (num_proc=2):   0%|          | 0/7441 [00:00<?, ? examples/s]
# Tokenizing eval dataset (num_proc=2):   0%|          | 0/7441 [00:00<?, ? examples/s]
# Truncating eval dataset (num_proc=2):   0%|          | 0/7441 [00:00<?, ? examples/s]

# %% [markdown]
# # Checking Masks

# %%
found_ids = None
found_labels = None
print("Searching for a sample with less than p50 tokens...")
for batch in trainer.get_train_dataloader():
    for i in range(len(batch["input_ids"])):
        ids = batch["input_ids"][i]
        if len(ids) < 110:
            found_ids = ids
            found_labels = batch["labels"][i]
            break    
    if found_ids is not None:
        break
# Out:
# Searching for a sample with less than p50 tokens...

# %%
batch["labels"][i]
# Out:
# tensor([ -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
#          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
#          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
#          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
#          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
#          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
#          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
#          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
#          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
#          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
#          -100,  -100,  -100,  3069,  1146,  1032, 26605, 29572,     2],
#        device='cuda:0')

# %%
 if found_ids is not None:
    active = (found_labels != -100).nonzero().flatten()

    if len(active):
        s = int(active[0])
        print("\n--- PROMPT (Loss Ignored) ---")
        print(trainer.processing_class.decode(found_ids[:s]))
        print("\n--- COMPLETION (Loss Calculated) ---")
        print(trainer.processing_class.decode(found_ids[s:])) 
    else:
        print("No active labels found in this sample.")
else:
    print("Could not find any samples under 200 tokens in the dataset.")
# Out:
# --- PROMPT (Loss Ignored) ---
# <s><s>[INST] You play 20 Questions. Ask the most informative next yes/no question. The keyword is a simple single-word noun known by most people. Start Broad And divide possibilities in half. Then Narrow Systematically. Do not ask the same question twice
#
# Game history:
# Q: Is it an animal?
# A: no.
# Q: Is it an inanimate object?
# A: yes.
#
# Only output a single yes/no question.[/INST]
#
# --- COMPLETION (Loss Calculated) ---
# Is it a mineral?</s>

# %% [markdown]
# # Start Fine-Tuning

# %%
# Now let's perform SFT:
from pathlib import Path
from transformers.trainer_utils import get_last_checkpoint
from huggingface_hub import snapshot_download

def prepare_resume(output_dir: str, repo_id: str):
    # 1) try local (works during a single Kaggle session)
    local = get_last_checkpoint(output_dir)
    if local:
        return local

    # 2) otherwise pull from the Hub (needs "Internet" ON in Kaggle settings)
    snapshot_download(
        repo_id=repo_id,
        local_dir=output_dir, local_dir_use_symlinks=False,
        allow_patterns=["last-checkpoint/*", "checkpoint-*/*"],  # only what we need
    )
    last = Path(output_dir) / "last-checkpoint"
    if last.exists():
        return str(last)
    ckpts = sorted(Path(output_dir).glob("checkpoint-*"),
                   key=lambda p: int(p.name.split("-")[-1]))
    return str(ckpts[-1]) if ckpts else None


print("--- Starting training Part 1 (up to 3000 steps) ---")
trainer.args.max_steps = 3001
resume_path = prepare_resume("./results", hub_model_id)
trainer.train(resume_from_checkpoint=resume_path or None)
print("--- Finished training Part 1 ---")

wandb.finish()
# Out:
# --- Starting training Part 1 (up to 3000 steps) ---
# Fetching 0 files: 0it [00:00, ?it/s]
#     <div>
#
#       <progress value='3001' max='3001' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3001/3001 5:20:13, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>0.450500</td>
#       <td>0.470896</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.430900</td>
#       <td>0.429644</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.420000</td>
#       <td>0.418181</td>
#     </tr>
#   </tbody>
# </table><p>
# Step 200: Training Loss = 0.7367
# Step 400: Training Loss = 0.4964
# Step 600: Training Loss = 0.4936
# Step 800: Training Loss = 0.4648
# Step 1000: Training Loss = 0.4505
# Step 1200: Training Loss = 0.4700
# Step 1400: Training Loss = 0.4484
# Step 1600: Training Loss = 0.4521
# Step 1800: Training Loss = 0.4521
# Step 2000: Training Loss = 0.4309
# Step 2200: Training Loss = 0.4126
# Step 2400: Training Loss = 0.4159
# Step 2600: Training Loss = 0.4117
# Step 2800: Training Loss = 0.4144
# Step 3000: Training Loss = 0.4200
# --- Finished training Part 1 ---
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>█▃▁</td></tr><tr><td>eval/mean_token_accuracy</td><td>▁▆█</td></tr><tr><td>eval/num_tokens</td><td>▁▅█</td></tr><tr><td>eval/runtime</td><td>█▁▄</td></tr><tr><td>eval/samples_per_second</td><td>▁█▅</td></tr><tr><td>eval/steps_per_second</td><td>▁█▁</td></tr><tr><td>train/epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▇▇███</td></tr><tr><td>train/grad_norm</td><td>█▄▃▃▂▄▂▂▂▁▂▁▂▁▁</td></tr><tr><td>train/learning_rate</td><td>███▇▆▆▅▄▄▃▂▂▁▁▁</td></tr><tr><td>train/loss</td><td>█▃▃▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>train/mean_token_accuracy</td><td>▄▇▇▇█▇▇▇▇██████▁</td></tr><tr><td>train/num_tokens</td><td>▁▁▂▂▃▃▄▄▅▆▆▆▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>0.41818</td></tr><tr><td>eval/mean_token_accuracy</td><td>0.88097</td></tr><tr><td>eval/num_tokens</td><td>4610791.0</td></tr><tr><td>eval/runtime</td><td>1541.3245</td></tr><tr><td>eval/samples_per_second</td><td>4.826</td></tr><tr><td>eval/steps_per_second</td><td>0.603</td></tr><tr><td>total_flos</td><td>1.977799707144192e+17</td></tr><tr><td>train/epoch</td><td>0.09982</td></tr><tr><td>train/global_step</td><td>3001</td></tr><tr><td>train/grad_norm</td><td>0.23756</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.42</td></tr><tr><td>train/mean_token_accuracy</td><td>0.78558</td></tr><tr><td>train/num_tokens</td><td>4614087.0</td></tr><tr><td>train_loss</td><td>0.46483</td></tr><tr><td>train_runtime</td><td>19223.856</td></tr><tr><td>train_samples_per_second</td><td>1.249</td></tr><tr><td>train_steps_per_second</td><td>0.156</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">swept-blaze-10</strong> at: <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/z9109u7y' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/z9109u7y</a><br> View project at: <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250821_231229-z9109u7y/logs</code>

# %%
# Cell 2
from transformers.trainer_utils import get_last_checkpoint

# --- Re-initialize W&B in "resume" mode ---
print(f"Resuming W&B run with ID: {run_id}")
wandb.init(project="mistral-20q-finetune-resumed", id=run_id, resume= 'auto')

# --- Modify the arguments of the EXISTING trainer ---
print("Updating trainer arguments for Part 2")
trainer.args.max_steps = 5000            

print("--- Starting training Part 2 (from 400 to 600 steps) ---")
# Resume training
resume_path = prepare_resume("./results", hub_model_id)
trainer.train(resume_from_checkpoint=resume_path or None)
print("--- Finished training Part 2 ---")

wandb.finish()
# Out:
# Resuming W&B run with ID: z9109u7y
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250822_043951-z9109u7y</code>
# Syncing run <strong><a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed/runs/z9109u7y' target="_blank">rare-sunset-2</a></strong> to <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed</a>
#  View run at <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed/runs/z9109u7y' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed/runs/z9109u7y</a>
# Updating trainer arguments for Part 2
# --- Starting training Part 2 (from 400 to 600 steps) ---
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 3:32:52, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4000</td>
#       <td>0.396700</td>
#       <td>0.416607</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.400100</td>
#       <td>0.412342</td>
#     </tr>
#   </tbody>
# </table><p>
# Step 3200: Training Loss = 0.4180
# Step 3400: Training Loss = 0.4200
# Step 3600: Training Loss = 0.4108
# Step 3800: Training Loss = 0.3961
# Step 4000: Training Loss = 0.3967
# Step 4200: Training Loss = 0.4137
# Step 4400: Training Loss = 0.4015
# Step 4600: Training Loss = 0.3889
# Step 4800: Training Loss = 0.4168
# Step 5000: Training Loss = 0.4001
# --- Finished training Part 2 ---
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>█▁</td></tr><tr><td>eval/mean_token_accuracy</td><td>▁█</td></tr><tr><td>eval/num_tokens</td><td>▁█</td></tr><tr><td>eval/runtime</td><td>█▁</td></tr><tr><td>eval/samples_per_second</td><td>▁█</td></tr><tr><td>eval/steps_per_second</td><td>▁▁</td></tr><tr><td>train/epoch</td><td>▁▂▃▃▄▄▅▆▆▇███</td></tr><tr><td>train/global_step</td><td>▁▂▃▃▄▄▅▆▆▇███</td></tr><tr><td>train/grad_norm</td><td>▂▃█▂▃▂▂▁▁▁</td></tr><tr><td>train/learning_rate</td><td>█▇▅▄▃▃▂▁▁▁</td></tr><tr><td>train/loss</td><td>██▆▃▃▇▄▁▇▄</td></tr><tr><td>train/mean_token_accuracy</td><td>▂▂▁▇▆▅▆█▄▄</td></tr><tr><td>train/num_tokens</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>0.41234</td></tr><tr><td>eval/mean_token_accuracy</td><td>0.88224</td></tr><tr><td>eval/num_tokens</td><td>7664308.0</td></tr><tr><td>eval/runtime</td><td>1543.7381</td></tr><tr><td>eval/samples_per_second</td><td>4.819</td></tr><tr><td>eval/steps_per_second</td><td>0.602</td></tr><tr><td>total_flos</td><td>3.285436704175227e+17</td></tr><tr><td>train/epoch</td><td>0.16631</td></tr><tr><td>train/global_step</td><td>5000</td></tr><tr><td>train/grad_norm</td><td>0.16977</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.4001</td></tr><tr><td>train/mean_token_accuracy</td><td>0.88538</td></tr><tr><td>train/num_tokens</td><td>7664308.0</td></tr><tr><td>train_loss</td><td>0.16242</td></tr><tr><td>train_runtime</td><td>12780.6178</td></tr><tr><td>train_samples_per_second</td><td>3.13</td></tr><tr><td>train_steps_per_second</td><td>0.391</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rare-sunset-2</strong> at: <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed/runs/z9109u7y' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed/runs/z9109u7y</a><br> View project at: <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250822_043951-z9109u7y/logs</code>

# %% [markdown]
# <font color="blue">At this step of final code, the execution was interupted because of electricity cut. fortunately the 6000-step checkpoint was truely pushed to HF, so let's resume from there (step 5000 to 6000 logs are not shown here)

# %%
# Cell 2
from transformers.trainer_utils import get_last_checkpoint

# --- Re-initialize W&B in "resume" mode ---
print(f"Resuming W&B run with ID: {run_id}")
wandb.init(project="mistral-20q-finetune-resumed", id=run_id, resume= 'auto')

# --- Modify the arguments of the EXISTING trainer ---
print("Updating trainer arguments for Part 3")
trainer.args.max_steps = 10000            

print("--- Starting training Part 3 (from 5000 to 10000 steps) ---")
# Resume training
resume_path = prepare_resume("./results", hub_model_id)
trainer.train(resume_from_checkpoint=resume_path or None)
print("--- Finished training Part 3 ---")

wandb.finish()
# Out:
# Resuming W&B run with ID: f8tsl6x3
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">lunar-sun-12</strong> at: <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/f8tsl6x3' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune/runs/f8tsl6x3</a><br> View project at: <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250822_134211-f8tsl6x3/logs</code>
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250822_134912-f8tsl6x3</code>
# Syncing run <strong><a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed/runs/f8tsl6x3' target="_blank">hardy-bird-4</a></strong> to <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed</a>
#  View run at <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed/runs/f8tsl6x3' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed/runs/f8tsl6x3</a>
# Updating trainer arguments for Part 3
# --- Starting training Part 3 (from 5000 to 10000 steps) ---
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:982: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# rng_state.pth:   0%|          | 0.00/14.2k [00:00<?, ?B/s]
# scheduler.pt:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/54.6M [00:00<?, ?B/s]
# scaler.pt:   0%|          | 0.00/988 [00:00<?, ?B/s]
# optimizer.pt:   0%|          | 0.00/28.7M [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/896 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# training_args.bin:   0%|          | 0.00/5.75k [00:00<?, ?B/s]
# trainer_state.json: 0.00B [00:00, ?B/s]
#     <div>
#
#       <progress value='10000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10000/10000 7:14:39, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>7000</td>
#       <td>0.404200</td>
#       <td>0.403630</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.401700</td>
#       <td>0.399362</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.391200</td>
#       <td>0.395003</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.410300</td>
#       <td>0.394489</td>
#     </tr>
#   </tbody>
# </table><p>
# Step 6200: Training Loss = 0.4151
# Step 6400: Training Loss = 0.4101
# Step 6600: Training Loss = 0.4001
# Step 6800: Training Loss = 0.4028
# Step 7000: Training Loss = 0.4042
# Step 7200: Training Loss = 0.4014
# Step 7400: Training Loss = 0.4016
# Step 7600: Training Loss = 0.4056
# Step 7800: Training Loss = 0.3997
# Step 8000: Training Loss = 0.4017
# Step 8200: Training Loss = 0.4155
# Step 8400: Training Loss = 0.4032
# Step 8600: Training Loss = 0.3851
# Step 8800: Training Loss = 0.4012
# Step 9000: Training Loss = 0.3912
# Step 9200: Training Loss = 0.3988
# Step 9400: Training Loss = 0.3920
# Step 9600: Training Loss = 0.4036
# Step 9800: Training Loss = 0.3784
# Step 10000: Training Loss = 0.4103
# --- Finished training Part 3 ---
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>█▅▁▁</td></tr><tr><td>eval/mean_token_accuracy</td><td>▁▄█▇</td></tr><tr><td>eval/num_tokens</td><td>▁▃▆█</td></tr><tr><td>eval/runtime</td><td>█▅▁▃</td></tr><tr><td>eval/samples_per_second</td><td>▁▄█▆</td></tr><tr><td>eval/steps_per_second</td><td>▁▅█▅</td></tr><tr><td>train/epoch</td><td>▁▁▂▂▂▂▃▃▄▄▄▄▅▅▅▆▆▆▇▇▇████</td></tr><tr><td>train/global_step</td><td>▁▁▂▂▂▂▃▃▄▄▄▄▅▅▅▆▆▆▇▇▇████</td></tr><tr><td>train/grad_norm</td><td>▂▁▁▃▄▁▃▃▂▅█▄▂▂▂▂▂▂▃▄</td></tr><tr><td>train/learning_rate</td><td>█▇▇▆▆▅▅▄▄▃▃▂▂▂▂▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▇▅▆▆▅▅▆▅▅█▆▂▅▃▅▄▆▁▇</td></tr><tr><td>train/mean_token_accuracy</td><td>▂▄▃▂▃▄▃▁▆▅▂▄▆▄▄▄▅▅█▁</td></tr><tr><td>train/num_tokens</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>0.39449</td></tr><tr><td>eval/mean_token_accuracy</td><td>0.88477</td></tr><tr><td>eval/num_tokens</td><td>6129685.0</td></tr><tr><td>eval/runtime</td><td>1579.9198</td></tr><tr><td>eval/samples_per_second</td><td>4.71</td></tr><tr><td>eval/steps_per_second</td><td>0.589</td></tr><tr><td>total_flos</td><td>6.646717324079923e+17</td></tr><tr><td>train/epoch</td><td>0.33255</td></tr><tr><td>train/global_step</td><td>10000</td></tr><tr><td>train/grad_norm</td><td>0.39423</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.4103</td></tr><tr><td>train/mean_token_accuracy</td><td>0.88275</td></tr><tr><td>train/num_tokens</td><td>6129685.0</td></tr><tr><td>train_loss</td><td>0.16043</td></tr><tr><td>train_runtime</td><td>26091.0095</td></tr><tr><td>train_samples_per_second</td><td>3.066</td></tr><tr><td>train_steps_per_second</td><td>0.383</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hardy-bird-4</strong> at: <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed/runs/f8tsl6x3' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed/runs/f8tsl6x3</a><br> View project at: <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250822_134912-f8tsl6x3/logs</code>

# %%
# Cell 2
from transformers.trainer_utils import get_last_checkpoint

# --- Re-initialize W&B in "resume" mode ---
print(f"Resuming W&B run with ID: {run_id}")
wandb.init(project="mistral-20q-finetune-resumed", id=run_id, resume= 'auto')

# --- Modify the arguments of the EXISTING trainer ---
print("Updating trainer arguments for Part 4")
trainer.args.max_steps = 14000            

print("--- Starting training Part 4 (from 10000 to 14000 steps) ---")
# Resume training
resume_path = prepare_resume("./results", hub_model_id)
trainer.train(resume_from_checkpoint=resume_path or None)
print("--- Finished training Part 4 ---")

wandb.finish()
# Out:
# Resuming W&B run with ID: f8tsl6x3
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250822_210644-f8tsl6x3</code>
# Resuming run <strong><a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed/runs/f8tsl6x3' target="_blank">hardy-bird-4</a></strong> to <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed</a>
#  View run at <a href='https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed/runs/f8tsl6x3' target="_blank">https://wandb.ai/shahriarbasiri-sharif-university-of-technology/mistral-20q-finetune-resumed/runs/f8tsl6x3</a>
# Updating trainer arguments for Part 4
# --- Starting training Part 4 (from 10000 to 14000 steps) ---
#     <div>
#
#       <progress value='11630' max='14000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11630/14000 2:41:13 < 3:54:42, 0.17 it/s, Epoch 0.39/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>11000</td>
#       <td>0.393600</td>
#       <td>0.397903</td>
#     </tr>
#   </tbody>
# </table><p>
# Step 10200: Training Loss = 0.4130
# Step 10400: Training Loss = 0.4069
# Step 10600: Training Loss = 0.3849
# Step 10800: Training Loss = 0.3947
# Step 11000: Training Loss = 0.3936
# Step 11200: Training Loss = 0.4096
# Step 11400: Training Loss = 0.3901
# Step 11600: Training Loss = 0.3867

# %% [markdown]
# # Evaluation

# %% [markdown]
# You can start from here. the model will be loaded from Hugging Face checkpoint.

# %%
# %%writefile test.py

import random
import torch
from typing import List, Dict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from huggingface_hub import login
import logging
logging.getLogger("transformers").setLevel(logging.ERROR)

GAME_WORDS = [
    "cat", "dog", "cow", "horse", "rabbit", "lion", "bear", "shark", "eagle", "ant",
    "apple", "banana", "orange", "carrot", "bread", "cheese", "pizza", "cookie", "egg", "ice-cream",
    "chair", "table", "sofa", "bed", "lamp", "clock", "mirror", "door", "window", "carpet",
    "car", "bicycle", "bus", "train", "airplane", "boat", "rocket", "helmet", "engine", "wheel",
    "pencil", "pen", "book", "paper", "scissors", "ruler", "eraser", "backpack", "laptop", "phone",
    "ball", "doll", "puzzle", "kite", "yo-yo", "drum", "guitar", "camera", "radio", "television",
    "shirt", "pants", "jacket", "hat", "shoes", "gloves", "umbrella", "watch", "glasses",
    "moon", "sun", "star", "cloud", "rain", "snow", "mountain", "river", "ocean", "island",
    "doctor", "teacher", "chef", "farmer", "artist", "pilot", "police", "firefighter", "singer", "dancer",
    "gold", "silver", "iron", "sand", "water", "oil", "soap", "sugar", "salt", "honey"
]

SYSTEM_PROMPT = "You are a precise answering engine. Based on the keyword and question, provide a 'Yes' or 'No' answer."
FEW_SHOT_EXAMPLES = """
[EXAMPLE 1]
Keyword: car
Question: Is it a living thing?
Answer: No
[EXAMPLE 2]
Keyword: water
Question: Is it used for cleaning?
Answer: Yes
[EXAMPLE 3]
Keyword: tree
Question: Is it man-made?
Answer: No
"""

class ValidatorModel:
    
    _model = None
    _tokenizer = None
    _words_dataset = None
    
    def __init__(self):

                
        if ValidatorModel._model is None: # Check if the model has already been loaded (by a previous instantiation)
            print("--- Loading model and tokenizer first time ---")
            login("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", add_to_git_credential=False)
            model_id = "mistralai/Mistral-7B-Instruct-v0.3"

            # Load and assign to the CLASS attributes
            ValidatorModel._tokenizer = AutoTokenizer.from_pretrained(model_id, use_fast=True)
            
            bnb_cfg = BitsAndBytesConfig(load_in_4bit=True,
                                         bnb_4bit_compute_dtype=torch.float16,
                                         bnb_4bit_use_double_quant=True,
                                         bnb_4bit_quant_type="nf4")

            ValidatorModel._model = AutoModelForCausalLM.from_pretrained(
                model_id,
                device_map="auto",
                quantization_config=bnb_cfg,
                trust_remote_code=True,
            ).eval()
            ValidatorModel._words_dataset = GAME_WORDS.copy()
            print("--- Model and tokenizer loaded and cached. ---")
        
        # Assign the cached model/tokenizer to this specific instance
        self.model = ValidatorModel._model
        self.tokenizer = ValidatorModel._tokenizer
        self.words_dataset = ValidatorModel._words_dataset
        
        self.keyword = random.choice(self.words_dataset)
        random.choice(self.words_dataset)
        print(f"\n--- Validator secret word: {self.keyword} ---")
        self.words_dataset.remove(self.keyword) # to not ask same word twice

    def _ask_ai(self, messages: List[Dict], max_new=8, temp=0.01) -> str:
        prompt = self.tokenizer.apply_chat_template(
            messages, tokenize=False, add_generation_prompt=True
        )
        inputs = self.tokenizer(prompt, return_tensors="pt").to(self.model.device)
        out = self.model.generate(
            **inputs,
            max_new_tokens=max_new,
            temperature=temp,
            eos_token_id=self.tokenizer.eos_token_id,
            pad_token_id=self.tokenizer.eos_token_id
        )
        return self.tokenizer.decode(out[0][inputs.input_ids.shape[1]:], skip_special_tokens=True).strip()

    def validate_question(self, question: str) -> str:
        user_content = f"{FEW_SHOT_EXAMPLES}\n[FINAL TASK]\nKeyword: {self.keyword}\nQuestion: {question}\nAnswer:"
        messages = [{"role": "system", "content": SYSTEM_PROMPT}, {"role": "user", "content": user_content}]
        model_ans = self._ask_ai(messages)
        return "yes" if "yes" in model_ans.lower() else "no"

    def validate_guess(self, guess: str) -> str:
        return 'Yes' if guess and self.keyword and guess.lower() == self.keyword.lower() else 'No'
# Out:
# Writing test.py

# %%
# %%writefile evaluate_20Q.py

import argparse
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from test import ValidatorModel
from huggingface_hub import login
import re 

# System prompt for the question-asking model
SYSTEM_PROMPT = "You play 20 Questions. Ask the most informative next yes/no question. The keyword is a simple single-word noun known by most people. Start Broad And divide possibilities in half. Then Narrow Systematically. Do not ask the same question twice"

class Agent:
    """
    An AI agent that uses a single fine-tuned model and disables the LoRA
    adapter to revert to base model behavior for guessing.
    """
    def __init__(self, model_id="shahriar7/mistral-7b-20q-finetuned"):
        print("Loading agent model (base + LoRA adapter)...")
        
        # Authenticate with Hugging Face
        login(token="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", add_to_git_credential=False)
        
        # 4-bit quantization configuration
        bnb_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_compute_dtype=torch.float16,
        )
        
        # Load the single model. Transformers will load the base and apply the adapter.
        self.model = AutoModelForCausalLM.from_pretrained(
            model_id,
            quantization_config=bnb_config,
            torch_dtype=torch.float16,
            device_map="auto",
            trust_remote_code=True,
        )
        self.tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
        self.tokenizer.pad_token = self.tokenizer.eos_token
        print("Agent model loaded successfully.")

    def _generate_response(self, model, messages, temperature=0.7, max_tokens=20):
        """Helper function to generate a response from a specific model."""
        prompt = self.tokenizer.apply_chat_template(
            messages, tokenize=False, add_generation_prompt=True
        )
        inputs = self.tokenizer(prompt, return_tensors="pt").to(model.device)
        
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_tokens,
            do_sample=True,
            temperature=temperature,
            top_p=0.9,
            pad_token_id=self.tokenizer.eos_token_id
        )
        
        response = self.tokenizer.decode(outputs[0][inputs.input_ids.shape[1]:], skip_special_tokens=True)
        return response.strip()

    def ask_question(self, history):
        """Uses the FINE-TUNED model with an improved strategic prompt."""
        history_str = "\n".join(history) if history else "No history yet. Start with a broad question."
        
        system_prompt = (
            "ou are playing a game of 20 Questions. Your task is to ask a strategic and simple 'yes' or 'no' question to help you guess the secret object "
            "Analyze the history carefully. Do not repeat questions. "
        )
        user_prompt = f""""Here is the game history so far:\n{history_str}\n\n
        Your most important rule is: "
        "**NEVER repeat a question that is already in the asked questions in history.**\n\n 
            Generate only the question."""
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
        
        # This call is correct, we'll make make_guess match it
        question = self._generate_response(self.model, messages, temperature=0.1, max_tokens=25)
        question = question.split('\n')[0].strip()

        temperature = 0.7
        for retry in range(4):
            if question in history_str:
                print("repeated question, highering temperature")
                temperature += 0.5
                messages[1]["content"]+= "\n\nATTENTION: Your last question was a repeat. You MUST generate a new, unique question."
                question = self._generate_response(self.model, messages, temperature=temperature, max_tokens=25)
                question = question.split('\n')[0].strip()
            else:
                break
            
        return question

    def make_guess(self, history):
        """Temporarily disables the adapter to use the BASE model for guessing."""
        history_str = "\n".join(history)
        
        system_prompt = (
            "You are playing a game of 20 Questions. Your task is to guess the secret item. Based on the provided history of questions and answers, your goal is to provide a single, concrete noun as your guess. Do not provide any explanation or surrounding text."
        )
        user_prompt = (
            f"Here is the history of the game so far: \n{history_str}\n\n "
            "Based on this information, what is your single-word guess for the secret item? Your answer must be a single common word"
            "Your answer must be only the single word you are guessing."
        )
        
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
        
        try:
            self.model.disable_adapters()
            # --- FIX IS HERE: Pass self.model to the function call ---
            guess = self._generate_response(self.model, messages, temperature=0.6, max_tokens=10)
        finally:
            self.model.enable_adapters()

        guess = guess.strip().split()[0]
        guess = re.sub(r"[^a-zA-Z]", "", guess).lower()
        return guess



def play_game(agent, validator):
    """
    Plays a single game of 20 Questions.
    Returns True if the agent wins, False otherwise.
    """
    history = []
    for turn in range(1, 21):
        print(f"\n--- Turn {turn} ---")
        
        # 1. Agent asks a question
        question = agent.ask_question(history)
        print(f"Agent Question: {question}")

        # 2. Validator provides an answer
        answer = validator.validate_question(question)
        print(f"Validator Answer: {answer}")
        
        # 3. Update history with the question and answer
        history.append(f"Q: {question}\nA: {answer}")

        # 4. Agent makes a guess
        guess = agent.make_guess(history)
        print(f"Agent Guess: {guess}")

        # 5. Validator checks the guess
        is_correct_str = validator.validate_guess(guess)
        
        if "yes" in is_correct_str.lower():
            print(f"Agent guessed correctly! The word was '{guess}'.")
            return True
        else:
            print("Agent's guess was incorrect.")
            # --- FIX IS HERE ---
            # Add the incorrect guess to the history for the model to learn from
            history.append(f"My guess '{guess}' was incorrect.")
            
    print(f"Agent failed to guess the word in 20 turns. The word was '{validator.keyword}'.")
    return False

def run_evaluation(num_games):
    """
    Runs the full evaluation for a specified number of games.
    """
    agent = Agent()
    wins = 0

    for i in range(num_games):
        print(f"\n====================\n  Starting Game {i + 1}/{num_games}\n====================")
        # A new validator is created for each game to get a new random word [cite: 78]
        validator = ValidatorModel() 
        if play_game(agent, validator):
            wins += 1
    
    print("\n--- Evaluation Finished ---")
    print(f"Final Score: {wins} / {num_games} wins ({wins/num_games:.2%})")


if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Evaluate a 20 Questions agent.")
    login("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", add_to_git_credential=False)
    parser.add_argument(
        "-N",
        "--num_games",
        type=int,
        required=True,
        help="The number of games to play for the evaluation."
    )
    args = parser.parse_args()
    
    run_evaluation(args.num_games)
# Out:
# Overwriting evaluate_20Q.py

# %%
# !python evaluate_20Q.py -N 10
# Out:
# Loading agent model (base + LoRA adapter)...
# 2025-08-25 22:47:32.272795: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756162052.294959     915 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756162052.301754     915 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:14<00:00,  4.92s/it]
# Agent model loaded successfully.
#
# ====================
#   Starting Game 1/10
# ====================
# --- Loading model and tokenizer first time ---
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:14<00:00,  4.99s/it]
# --- Model and tokenizer loaded and cached. ---
#
# --- Validator secret word: pencil ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: yes
# Agent Guess: hammer
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: computer
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: yes
# Agent Guess: phone
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: no
# Agent Guess: watch
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a type of electronic device?
# Validator Answer: no
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a type of appliance?
# Validator Answer: no
# Agent Guess: camera
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a type of household item?
# Validator Answer: yes
# Agent Guess: microwave
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a type of kitchen appliance?
# Validator Answer: no
# Agent Guess: refrigerator
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a type of entertainment device?
# Validator Answer: no
# Agent Guess: vacuum
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object a type of cleaning device?
# Validator Answer: no
# Agent Guess: radio
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is the object a type of gaming device?
# Validator Answer: no
# Agent Guess: oven
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object a type of audio device?
# Validator Answer: no
# Agent Guess: vacuum
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is the object a type of appliance that is used for cooking?
# Validator Answer: no
# Agent Guess: dishwasher
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object a type of appliance that is used for storage?
# Validator Answer: no
# Agent Guess: toaster
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is the object a type of appliance that is used for cleaning?
# Validator Answer: no
# Agent Guess: washing
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is the object a type of appliance that is used for decoration?
# Validator Answer: no
# Agent Guess: iron
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is the object a type of appliance that is used for lighting?
# Validator Answer: no
# Agent Guess: mixer
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is the object a type of appliance that is used for heating?
# Validator Answer: no
# Agent Guess: air
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'pencil'.
#
# ====================
#   Starting Game 2/10
# ====================
#
# --- Validator secret word: moon ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: no
# Agent Guess: animal
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: plant
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: water
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: rock
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: air
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: soil
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: cloud
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: ocean
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: star
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: moon
# Agent guessed correctly! The word was 'moon'.
#
# ====================
#   Starting Game 3/10
# ====================
#
# --- Validator secret word: engine ---
#
# --- Turn 1 ---
# Agent Question: Is the object an animal?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object a tool?
# Validator Answer: yes
# Agent Guess: toolbox
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a handheld tool?
# Validator Answer: no
# Agent Guess: hammer
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object used for gardening?
# Validator Answer: no
# Agent Guess: saw
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object used for construction?
# Validator Answer: no
# Agent Guess: drill
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object used for cooking?
# Validator Answer: no
# Agent Guess: sawmill
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object used for painting?
# Validator Answer: no
# Agent Guess: sawmill
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object used for cutting?
# Validator Answer: no
# Agent Guess: saw
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object used for woodworking?
# Validator Answer: no
# Agent Guess: sawmill
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object used for measuring?
# Validator Answer: no
# Agent Guess: pencil
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object used for drilling?
# Validator Answer: no
# Agent Guess: wrench
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object used for hammering?
# Validator Answer: no
# Agent Guess: wrench
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is the object used for cutting?
# Validator Answer: no
# Agent Guess: sawmill
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object a saw?
# Validator Answer: no
# Agent Guess: scissors
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is the object a sawmill?
# Validator Answer: no
# Agent Guess: keyboard
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object a sawmill?
# Validator Answer: no
# Agent Guess: wrench
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is the object a sawmill?
# Validator Answer: no
# Agent Guess: screwdriver
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is the object a sawmill?
# Validator Answer: no
# Agent Guess: socket
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is the object a sawmill?
# Validator Answer: no
# Agent Guess: pliers
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is the object a sawmill?
# Validator Answer: no
# Agent Guess: wrench
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'engine'.
#
# ====================
#   Starting Game 4/10
# ====================
#
# --- Validator secret word: pants ---
#
# --- Turn 1 ---
# Agent Question: Is it an animal?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it an inanimate object?
# Validator Answer: yes
# Agent Guess: vehicle
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it an item of clothing?
# Validator Answer: yes
# Agent Guess: shoe
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it a hat?
# Validator Answer: no
# Agent Guess: glasses
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it a piece of jewelry?
# Validator Answer: no
# Agent Guess: clothing
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it a scarf?
# Validator Answer: no
# Agent Guess: belt
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is it a shirt?
# Validator Answer: no
# Agent Guess: pants
# Agent guessed correctly! The word was 'pants'.
#
# ====================
#   Starting Game 5/10
# ====================
#
# --- Validator secret word: gloves ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: computer
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: yes
# Agent Guess: hammer
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: instrument
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a household item?
# Validator Answer: yes
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a kitchen appliance?
# Validator Answer: no
# Agent Guess: door
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a bathroom item?
# Validator Answer: no
# Agent Guess: microwave
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: yes
# Agent Guess: shoe
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a hat?
# Validator Answer: no
# Agent Guess: jacket
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a scarf?
# Validator Answer: no
# Agent Guess: clothes
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object a belt?
# Validator Answer: no
# Agent Guess: tie
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is the object a pair of gloves?
# Validator Answer: yes
# Agent Guess: pants
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object a pair of shoes?
# Validator Answer: no
# Agent Guess: glove
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is the object a pair of socks?
# Validator Answer: no
# Agent Guess: mittens
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object a pair of gloves?
# Validator Answer: yes
# Agent Guess: mittens
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is the object a pair of gloves?
# Validator Answer: yes
# Agent Guess: gloves
# Agent guessed correctly! The word was 'gloves'.
#
# ====================
#   Starting Game 6/10
# ====================
#
# --- Validator secret word: star ---
#
# --- Turn 1 ---
# Agent Question: Is it an animal?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it a man-made object?
# Validator Answer: no
# Agent Guess: plant
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it an inanimate object?
# Validator Answer: yes
# Agent Guess: rock
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: water
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it a solid object?
# Validator Answer: no
# Agent Guess: liquid
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: gas
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: plasma
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: air
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: soil
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: metal
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: wood
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: food
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: paper
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: glass
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: light
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: art
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: electricity
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: cloud
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: based
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: soil
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'star'.
#
# ====================
#   Starting Game 7/10
# ====================
#
# --- Validator secret word: airplane ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: yes
# Agent Guess: hammer
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object used for construction?
# Validator Answer: no
# Agent Guess: telephone
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object used for cooking?
# Validator Answer: no
# Agent Guess: keyboard
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object used for communication?
# Validator Answer: no
# Agent Guess: pen
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object used for entertainment?
# Validator Answer: no
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object used for writing?
# Validator Answer: no
# Agent Guess: pencil
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object used for drawing?
# Validator Answer: no
# Agent Guess: pencil
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object used for crafting?
# Validator Answer: no
# Agent Guess: piano
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object used for playing music?
# Validator Answer: no
# Agent Guess: wrench
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object used for gardening?
# Validator Answer: no
# Agent Guess: watch
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is the object used for painting?
# Validator Answer: no
# Agent Guess: sword
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object used for measuring?
# Validator Answer: no
# Agent Guess: desk
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is the object used for writing?
# Validator Answer: no
# Agent Guess: compass
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object used for measuring?
# Validator Answer: no
# Agent Guess: light
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is the object used for painting?
# Validator Answer: no
# Agent Guess: pencil
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is the object used for writing?
# Validator Answer: no
# Agent Guess: pencil
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is the object used for writing?
# Validator Answer: no
# Agent Guess: pencil
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is the object used for writing?
# Validator Answer: no
# Agent Guess: computer
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'airplane'.
#
# ====================
#   Starting Game 8/10
# ====================
#
# --- Validator secret word: watch ---
#
# --- Turn 1 ---
# Agent Question: Is it an animal?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it a man-made object?
# Validator Answer: yes
# Agent Guess: computer
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it a tool or machine?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it a piece of technology?
# Validator Answer: yes
# Agent Guess: phone
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it a form of transportation?
# Validator Answer: no
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it a piece of furniture?
# Validator Answer: no
# Agent Guess: appliance
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is it a type of electronic device?
# Validator Answer: yes
# Agent Guess: radio
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is it a type of computer?
# Validator Answer: no
# Agent Guess: printer
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is it a type of game console?
# Validator Answer: no
# Agent Guess: microwave
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is it a type of television?
# Validator Answer: no
# Agent Guess: video
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is it a type of gaming console?
# Validator Answer: no
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is it a type of speaker?
# Validator Answer: no
# Agent Guess: game
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is it a type of gaming console?
# Validator Answer: no
# Agent Guess: switch
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is it a type of headset?
# Validator Answer: no
# Agent Guess: console
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is it a type of microphone?
# Validator Answer: no
# Agent Guess: headphones
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is it a type of camera?
# Validator Answer: no
# Agent Guess: game
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is it a type of microphone?
# Validator Answer: no
# Agent Guess: my
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is it a type of headset?
# Validator Answer: no
# Agent Guess: game
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is it a type of gaming console?
# Validator Answer: no
# Agent Guess: projector
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is it a type of gaming console?
# Validator Answer: no
# Agent Guess: television
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'watch'.
#
# ====================
#   Starting Game 9/10
# ====================
#
# --- Validator secret word: hat ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: no
# Agent Guess: furniture
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: building
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: yes
# Agent Guess: shoe
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a hat?
# Validator Answer: yes
# Agent Guess: glove
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a scarf?
# Validator Answer: no
# Agent Guess: hat
# Agent guessed correctly! The word was 'hat'.
#
# ====================
#   Starting Game 10/10
# ====================
#
# --- Validator secret word: scissors ---
#
# --- Turn 1 ---
# Agent Question: Is it an animal?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is it a plant?
# Validator Answer: no
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is it a mineral?
# Validator Answer: no
# Agent Guess: book
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is it a man-made object?
# Validator Answer: yes
# Agent Guess: computer
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is it a tool?
# Validator Answer: yes
# Agent Guess: hammer
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is it a piece of furniture?
# Validator Answer: no
# Agent Guess: phone
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is it a piece of technology?
# Validator Answer: yes
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is it a piece of clothing?
# Validator Answer: no
# Agent Guess: phone
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is it a piece of furniture?
# Validator Answer: no
# Agent Guess: appliance
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is it a kitchen appliance?
# Validator Answer: no
# Agent Guess: gadget
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is it a piece of technology?
# Validator Answer: yes
# Agent Guess: microwave
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is it a piece of technology that is used in the home?
# Validator Answer: yes
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is it a piece of technology that is used in the kitchen?
# Validator Answer: yes
# Agent Guess: oven
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is it a kitchen appliance?
# Validator Answer: no
# Agent Guess: toaster
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is it a kitchen appliance?
# Validator Answer: no
# Agent Guess: refrigerator
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is it a kitchen appliance?
# Validator Answer: no
# Agent Guess: blender
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is it a kitchen appliance?
# Validator Answer: no
# Agent Guess: toaster
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is it a kitchen appliance?
# Validator Answer: no
# Agent Guess: coffee
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is it a kitchen appliance?
# Validator Answer: no
# Agent Guess: kettle
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is it a kitchen appliance?
# Validator Answer: no
# Agent Guess: coffee
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'scissors'.
#
# --- Evaluation Finished ---
# Final Score: 4 / 10 wins (40.00%)

# %%
# !python evaluate_20Q.py -N 10
# Out:
# Loading agent model (base + LoRA adapter)...
# 2025-08-25 23:06:29.619946: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756163189.642506     969 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756163189.649291     969 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:14<00:00,  4.92s/it]
# Agent model loaded successfully.
#
# ====================
#   Starting Game 1/10
# ====================
# --- Loading model and tokenizer first time ---
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:14<00:00,  4.88s/it]
# --- Model and tokenizer loaded and cached. ---
#
# --- Validator secret word: boat ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: yes
# Agent Guess: hammer
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: yes
# Agent Guess: computer
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: phone
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: no
# Agent Guess: appliance
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a kitchen appliance?
# Validator Answer: no
# Agent Guess: gadget
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a piece of technology used for entertainment?
# Validator Answer: no
# Agent Guess: gaming
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a piece of technology used for communication?
# Validator Answer: no
# Agent Guess: device
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a piece of technology used for transportation?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a plane?
# Validator Answer: no
# Agent Guess: train
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object a boat?
# Validator Answer: yes
# Agent Guess: ship
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is the object a submarine?
# Validator Answer: no
# Agent Guess: yacht
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object a sailboat?
# Validator Answer: yes
# Agent Guess: boat
# Agent guessed correctly! The word was 'boat'.
#
# ====================
#   Starting Game 2/10
# ====================
#
# --- Validator secret word: bread ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: computer
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: no
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: book
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: no
# Agent Guess: appliance
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: artwork
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a household item?
# Validator Answer: yes
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a kitchen appliance?
# Validator Answer: no
# Agent Guess: door
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: fridge
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: light
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: piano
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: light
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: table
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: phone
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: wall
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: lamp
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: picture
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: window
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: plug
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: light
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'bread'.
#
# ====================
#   Starting Game 3/10
# ====================
#
# --- Validator secret word: singer ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: yes
# Agent Guess: animal
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object a mammal?
# Validator Answer: no
# Agent Guess: plant
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a bird?
# Validator Answer: no
# Agent Guess: tree
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a reptile?
# Validator Answer: no
# Agent Guess: fungus
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a fish?
# Validator Answer: no
# Agent Guess: insect
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a amphibian?
# Validator Answer: no
# Agent Guess: my
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a plant?
# Validator Answer: no
# Agent Guess: algae
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a flower?
# Validator Answer: no
# Agent Guess: coral
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a moss?
# Validator Answer: no
# Agent Guess: fungus
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a lichen?
# Validator Answer: no
# Agent Guess: algae
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a moss?
# Validator Answer: no
# Agent Guess: algae
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object a moss?
# Validator Answer: no
# Agent Guess: fungus
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is the object a moss?
# Validator Answer: no
# Agent Guess: algae
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object a moss?
# Validator Answer: no
# Agent Guess: algae
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is the object a moss?
# Validator Answer: no
# Agent Guess: my
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object a moss?
# Validator Answer: no
# Agent Guess: algae
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is the object a moss?
# Validator Answer: no
# Agent Guess: animal
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is the object a moss?
# Validator Answer: no
# Agent Guess: based
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is the object a moss?
# Validator Answer: no
# Agent Guess: based
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is the object a moss?
# Validator Answer: no
# Agent Guess: based
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'singer'.
#
# ====================
#   Starting Game 4/10
# ====================
#
# --- Validator secret word: ice-cream ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: no
# Agent Guess: furniture
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: book
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: no
# Agent Guess: pencil
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: painting
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a piece of art?
# Validator Answer: no
# Agent Guess: appliance
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: instrument
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: building
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: door
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: light
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: bookshelf
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: desk
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: phone
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: paper
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: lamp
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: piano
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: pocket
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: keyboard
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: lightbulb
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'ice-cream'.
#
# ====================
#   Starting Game 5/10
# ====================
#
# --- Validator secret word: salt ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: no
# Agent Guess: rock
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a mineral?
# Validator Answer: yes
# Agent Guess: crystal
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a mineral that is found in the earth?
# Validator Answer: yes
# Agent Guess: ore
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a mineral that is found in the ocean?
# Validator Answer: yes
# Agent Guess: salt
# Agent guessed correctly! The word was 'salt'.
#
# ====================
#   Starting Game 6/10
# ====================
#
# --- Validator secret word: bed ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: no
# Agent Guess: furniture
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: book
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: no
# Agent Guess: painting
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: yes
# Agent Guess: desk
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a chair?
# Validator Answer: no
# Agent Guess: table
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a bed?
# Validator Answer: yes
# Agent Guess: bedside
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a mattress?
# Validator Answer: yes
# Agent Guess: frame
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a bed frame?
# Validator Answer: no
# Agent Guess: bed
# Agent guessed correctly! The word was 'bed'.
#
# ====================
#   Starting Game 7/10
# ====================
#
# --- Validator secret word: oil ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: no
# Agent Guess: book
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: painting
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: building
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: no
# Agent Guess: instrument
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a piece of jewelry?
# Validator Answer: no
# Agent Guess: gadget
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a household item?
# Validator Answer: no
# Agent Guess: artwork
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: weapon
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: appliance
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: light
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: animal
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: instrument
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: plant
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: stone
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: river
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: mountain
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: tree
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: pencil
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: bridge
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'oil'.
#
# ====================
#   Starting Game 8/10
# ====================
#
# --- Validator secret word: mountain ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: no
# Agent Guess: rock
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: tree
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a plant?
# Validator Answer: no
# Agent Guess: water
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: soil
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: air
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: ocean
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: cloud
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: stone
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: moon
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: star
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: sun
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: earth
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: wind
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: animal
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: fire
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: ocean
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: my
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: ocean
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: mountain
# Agent guessed correctly! The word was 'mountain'.
#
# ====================
#   Starting Game 9/10
# ====================
#
# --- Validator secret word: water ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: no
# Agent Guess: rock
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: tree
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a plant?
# Validator Answer: no
# Agent Guess: water
# Agent guessed correctly! The word was 'water'.
#
# ====================
#   Starting Game 10/10
# ====================
#
# --- Validator secret word: firefighter ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: yes
# Agent Guess: hammer
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: watch
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: instrument
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: no
# Agent Guess: weapon
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a kitchen appliance?
# Validator Answer: no
# Agent Guess: instrument
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a musical instrument?
# Validator Answer: no
# Agent Guess: tool
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a tool used for gardening?
# Validator Answer: no
# Agent Guess: pencil
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a tool used for construction?
# Validator Answer: no
# Agent Guess: gadget
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a tool used for painting?
# Validator Answer: no
# Agent Guess: furniture
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object a tool used for writing?
# Validator Answer: no
# Agent Guess: weapon
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is the object a tool used for cutting?
# Validator Answer: no
# Agent Guess: saw
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object a tool used for measuring?
# Validator Answer: no
# Agent Guess: key
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is the object a tool used for drilling?
# Validator Answer: no
# Agent Guess: pencil
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object a tool used for hammering?
# Validator Answer: no
# Agent Guess: screwdriver
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is the object a tool used for screwing?
# Validator Answer: no
# Agent Guess: puzzle
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is the object a tool used for measuring?
# Validator Answer: no
# Agent Guess: spectacles
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is the object a tool used for measuring?
# Validator Answer: no
# Agent Guess: door
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is the object a tool used for measuring?
# Validator Answer: no
# Agent Guess: desk
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'firefighter'.
#
# --- Evaluation Finished ---
# Final Score: 5 / 10 wins (50.00%)

# %%
# !python evaluate_20Q.py -N 10
# Out:
# Loading agent model (base + LoRA adapter)...
# 2025-08-25 23:19:46.427112: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756163986.451659     996 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756163986.458733     996 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:14<00:00,  4.81s/it]
# Agent model loaded successfully.
#
# ====================
#   Starting Game 1/10
# ====================
# --- Loading model and tokenizer first time ---
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:14<00:00,  4.87s/it]
# --- Model and tokenizer loaded and cached. ---
#
# --- Validator secret word: pilot ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: no
# Agent Guess: furniture
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: yes
# Agent Guess: computer
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of electronic equipment?
# Validator Answer: no
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: phone
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: no
# Agent Guess: appliance
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# repeated question, highering temperature
# Agent Question: Is the object a toy?
# Validator Answer: no
# Agent Guess: radio
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# repeated question, highering temperature
# Agent Question: Is the object a kitchenware?
# Validator Answer: no
# Agent Guess: microwave
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# repeated question, highering temperature
# Agent Question: Is the object a musical instrument?
# Validator Answer: no
# Agent Guess: appliance
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a household item?
# Validator Answer: no
# Agent Guess: game
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# repeated question, highering temperature
# Agent Question: Is the object a kitchen appliance?
# Validator Answer: no
# Agent Guess: fridge
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object a piece of office equipment?
# Validator Answer: no
# Agent Guess: lightbulb
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# repeated question, highering temperature
# Agent Question: Is the object a piece of home decoration?
# Validator Answer: no
# Agent Guess: light
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object used to hold food?
# Validator Answer: no
# Agent Guess: watch
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# repeated question, highering temperature
# Agent Question: Is the object used for entertainment?
# Validator Answer: no
# Agent Guess: lightswitch
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is the object used for communication?
# Validator Answer: no
# Agent Guess: light
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is the object used for lighting?
# Validator Answer: no
# Agent Guess: telephone
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is the object used for heating?
# Validator Answer: no
# Agent Guess: speaker
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is the object used for cooling?
# Validator Answer: no
# Agent Guess: lamp
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'pilot'.
#
# ====================
#   Starting Game 2/10
# ====================
#
# --- Validator secret word: dog ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: yes
# Agent Guess: animal
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object a mammal?
# Validator Answer: yes
# Agent Guess: lion
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a domesticated animal?
# Validator Answer: yes
# Agent Guess: dog
# Agent guessed correctly! The word was 'dog'.
#
# ====================
#   Starting Game 3/10
# ====================
#
# --- Validator secret word: moon ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: no
# Agent Guess: rock
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: tree
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a plant?
# Validator Answer: no
# Agent Guess: water
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# repeated question, highering temperature
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object artificial, organic, inanimate?
# Validator Answer: no
# Agent Guess: soil
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# repeated question, highering temperature
# Agent Question: Is the object edible?
# Validator Answer: no
# Agent Guess: air
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# repeated question, highering temperature
# Agent Question: Is the object mineral?
# Validator Answer: no
# Agent Guess: animal
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object a bird?
# Validator Answer: no
# Agent Guess: mountain
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# repeated question, highering temperature
# Agent Question: Is the object a reptile?
# Validator Answer: no
# Agent Guess: ocean
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a mammal?
# Validator Answer: no
# Agent Guess: stone
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a fish?
# Validator Answer: no
# Agent Guess: cloud
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# repeated question, highering temperature
# Agent Question: Is the object a human?
# Validator Answer: no
# Agent Guess: sun
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# repeated question, highering temperature
# Agent Question: Is the object a flower?
# Validator Answer: no
# Agent Guess: moon
# Agent guessed correctly! The word was 'moon'.
#
# ====================
#   Starting Game 4/10
# ====================
#
# --- Validator secret word: oil ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: computer
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: no
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: book
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: no
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a household appliance?
# Validator Answer: no
# Agent Guess: painting
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: instrument
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a piece of artwork?
# Validator Answer: no
# Agent Guess: pencil
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a piece of jewelry?
# Validator Answer: no
# Agent Guess: door
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object made of metal?
# Validator Answer: no
# Agent Guess: light
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# repeated question, highering temperature
# Agent Question: Is the object a form of technology?
# Validator Answer: no
# Agent Guess: bookshelf
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object an electric appliance?
# Validator Answer: no
# Agent Guess: piano
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# repeated question, highering temperature
# Agent Question: Is the object a kitchen appliance?
# Validator Answer: no
# Agent Guess: lamp
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# repeated question, highering temperature
# Agent Question: Is the object an entertainment device?
# Validator Answer: no
# Agent Guess: vehicle
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# repeated question, highering temperature
# Agent Question: Is the object an electronic device?
# Validator Answer: no
# Agent Guess: furniture
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# repeated question, highering temperature
# Agent Question: Is the object a musical instrument?
# Validator Answer: no
# Agent Guess: sculpture
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# repeated question, highering temperature
# Agent Question: Is the object a household item?
# Validator Answer: no
# Agent Guess: pocket
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# repeated question, highering temperature
# Agent Question: Is the object a type of technology?
# Validator Answer: no
# Agent Guess: pipe
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# repeated question, highering temperature
# Agent Question: Is the object a type of clothing?
# Validator Answer: no
# Agent Guess: bridge
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# repeated question, highering temperature
# Agent Question: Is the object a piece of art?
# Validator Answer: no
# Agent Guess: pen
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'oil'.
#
# ====================
#   Starting Game 5/10
# ====================
#
# --- Validator secret word: pizza ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: no
# Agent Guess: furniture
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: book
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: no
# Agent Guess: painting
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: appliance
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a piece of artwork?
# Validator Answer: no
# Agent Guess: instrument
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object a piece of furniture or décor in someone's home?
# Validator Answer: no
# Agent Guess: lightbulb
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a piece of furniture or décor in someone's office?
# Validator Answer: no
# Agent Guess: gadget
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a piece of furniture or décor in someone's kitchen?
# Validator Answer: no
# Agent Guess: vehicle
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a piece of furniture or décor in someone's bedroom?
# Validator Answer: no
# Agent Guess: building
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object a piece of furniture or décor in someone's living room?
# Validator Answer: no
# Agent Guess: pocket
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is the object a piece of furniture or décor in someone's bathroom?
# Validator Answer: no
# Agent Guess: pencil
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# repeated question, highering temperature
# Agent Question: Is the object a piece of furniture or décor in someone's den or lounge?
# Validator Answer: no
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# repeated question, highering temperature
# Agent Question: Is the object a piece of furniture or décor in someone's attic?
# Validator Answer: no
# Agent Guess: bookshelf
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object a piece of furniture or décor in someone's garage?
# Validator Answer: no
# Agent Guess: piano
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object made of wood?
# Validator Answer: no
# Agent Guess: door
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# repeated question, highering temperature
# Agent Question: Is the object made of metal?
# Validator Answer: no
# Agent Guess: light
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object a tablecloth?
# Validator Answer: no
# Agent Guess: sculpture
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# repeated question, highering temperature
# Agent Question: Is the object a piece of furniture or décor in someone's backyard?
# Validator Answer: no
# Agent Guess: lamp
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'pizza'.
#
# ====================
#   Starting Game 6/10
# ====================
#
# --- Validator secret word: camera ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: yes
# Agent Guess: hammer
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: computer
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: yes
# Agent Guess: phone
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: no
# Agent Guess: watch
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a piece of technology used for entertainment?
# Validator Answer: yes
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a game console?
# Validator Answer: no
# Agent Guess: game
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a video game?
# Validator Answer: no
# Agent Guess: video
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a video game console?
# Validator Answer: no
# Agent Guess: computer
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# repeated question, highering temperature
# Agent Question: Is the object a video game console that is typically used for entertainment?
# Validator Answer: no
# Agent Guess: game
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object a game-related product or device?
# Validator Answer: no
# Agent Guess: headset
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object a sound system or a remote control?
# Validator Answer: no
# Agent Guess: gamecontroller
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object a game-related product or device in which game content can be downloaded from?
# Validator Answer: no
# Agent Guess: playstation
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# repeated question, highering temperature
# Agent Question: Is the object a game-related product or device that can be accessed through a mobile app?
# Validator Answer: no
# Agent Guess: xbox
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object a game-related product or device that can be accessed through a computer?
# Validator Answer: no
# Agent Guess: nintendo
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is the object a game-related product or device that can be accessed through a television?
# Validator Answer: no
# Agent Guess: streaming
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is the object a game-related product or device that can be accessed through a gaming console?
# Validator Answer: no
# Agent Guess: streaming
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object a game controller?
# Validator Answer: no
# Agent Guess: app
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# repeated question, highering temperature
# Agent Question: Is the object a video game controller?
# Validator Answer: no
# Agent Guess: dvd
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'camera'.
#
# ====================
#   Starting Game 7/10
# ====================
#
# --- Validator secret word: doll ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: no
# Agent Guess: book
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: computer
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: painting
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: no
# Agent Guess: building
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a household item?
# Validator Answer: yes
# Agent Guess: refrigerator
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a kitchen appliance?
# Validator Answer: no
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object a kitchen item?
# Validator Answer: no
# Agent Guess: light
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# repeated question, highering temperature
# Agent Question: Is the object used for cleaning?
# Validator Answer: no
# Agent Guess: vacuum
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object used for entertainment?
# Validator Answer: yes
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object a game?
# Validator Answer: yes
# Agent Guess: board
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# Agent Question: Is the object a card game?
# Validator Answer: no
# Agent Guess: movie
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object a video game?
# Validator Answer: no
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is the object a video game console?
# Validator Answer: no
# Agent Guess: puzzle
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# repeated question, highering temperature
# Agent Question: Is the object a toy?
# Validator Answer: yes
# Agent Guess: doll
# Agent guessed correctly! The word was 'doll'.
#
# ====================
#   Starting Game 8/10
# ====================
#
# --- Validator secret word: honey ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: no
# Agent Guess: rock
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a mineral?
# Validator Answer: no
# Agent Guess: tree
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a plant?
# Validator Answer: no
# Agent Guess: water
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object found in nature?
# Validator Answer: yes
# Agent Guess: soil
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# repeated question, highering temperature
# Agent Question: Is the object edible?
# Validator Answer: yes
# Agent Guess: fruit
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a vegetable?
# Validator Answer: no
# Agent Guess: animal
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object found on Earth?
# Validator Answer: yes
# Agent Guess: mushroom
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# repeated question, highering temperature
# Agent Question: Is the object an insect?
# Validator Answer: no
# Agent Guess: fungus
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# repeated question, highering temperature
# Agent Question: Is the object found in water?
# Validator Answer: no
# Agent Guess: mountain
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# repeated question, highering temperature
# Agent Question: Is the object a tree?
# Validator Answer: no
# Agent Guess: mushroom
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# Agent Question: Is the object a flower?
# Validator Answer: no
# Agent Guess: fruit
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# repeated question, highering temperature
# Agent Question: Is the object a shrub?
# Validator Answer: no
# Agent Guess: berries
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object a root vegetable?
# Validator Answer: no
# Agent Guess: fish
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is the object a type of grass?
# Validator Answer: no
# Agent Guess: grasshopper
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object a type of mushroom?
# Validator Answer: no
# Agent Guess: my
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# repeated question, highering temperature
# Agent Question: Is the object a type of plant?
# Validator Answer: no
# Agent Guess: fungus
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# repeated question, highering temperature
# Agent Question: Is the object a type of fruit?
# Validator Answer: no
# Agent Guess: based
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is the object a type of vegetable?
# Validator Answer: no
# Agent Guess: algae
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# repeated question, highering temperature
# repeated question, highering temperature
# Agent Question: Is the object green?
# Validator Answer: no
# Agent Guess: seaweed
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'honey'.
#
# ====================
#   Starting Game 9/10
# ====================
#
# --- Validator secret word: ice-cream ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: no
# Agent Guess: book
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: painting
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: no
# Agent Guess: building
# Agent's guess was incorrect.
#
# --- Turn 6 ---
# Agent Question: Is the object a piece of clothing?
# Validator Answer: no
# Agent Guess: artwork
# Agent's guess was incorrect.
#
# --- Turn 7 ---
# Agent Question: Is the object a piece of jewelry?
# Validator Answer: no
# Agent Guess: instrument
# Agent's guess was incorrect.
#
# --- Turn 8 ---
# Agent Question: Is the object a household item?
# Validator Answer: yes
# Agent Guess: appliance
# Agent's guess was incorrect.
#
# --- Turn 9 ---
# Agent Question: Is the object a kitchen item?
# Validator Answer: no
# Agent Guess: furniture
# Agent's guess was incorrect.
#
# --- Turn 10 ---
# Agent Question: Is the object a decoration?
# Validator Answer: no
# Agent Guess: door
# Agent's guess was incorrect.
#
# --- Turn 11 ---
# Agent Question: Is the object a piece of artwork?
# Validator Answer: no
# Agent Guess: light
# Agent's guess was incorrect.
#
# --- Turn 12 ---
# repeated question, highering temperature
# Agent Question: Is the object a rug?
# Validator Answer: no
# Agent Guess: lamp
# Agent's guess was incorrect.
#
# --- Turn 13 ---
# repeated question, highering temperature
# Agent Question: Is the object a chair?
# Validator Answer: no
# Agent Guess: table
# Agent's guess was incorrect.
#
# --- Turn 14 ---
# Agent Question: Is the object a bed?
# Validator Answer: no
# Agent Guess: television
# Agent's guess was incorrect.
#
# --- Turn 15 ---
# Agent Question: Is the object a couch?
# Validator Answer: no
# Agent Guess: fridge
# Agent's guess was incorrect.
#
# --- Turn 16 ---
# Agent Question: Is the object a desk?
# Validator Answer: no
# Agent Guess: shelf
# Agent's guess was incorrect.
#
# --- Turn 17 ---
# Agent Question: Is the object a bookcase?
# Validator Answer: no
# Agent Guess: radio
# Agent's guess was incorrect.
#
# --- Turn 18 ---
# Agent Question: Is the object a television stand?
# Validator Answer: no
# Agent Guess: window
# Agent's guess was incorrect.
#
# --- Turn 19 ---
# Agent Question: Is the object a cabinet?
# Validator Answer: no
# Agent Guess: dishwasher
# Agent's guess was incorrect.
#
# --- Turn 20 ---
# Agent Question: Is the object a refrigerator?
# Validator Answer: no
# Agent Guess: vase
# Agent's guess was incorrect.
# Agent failed to guess the word in 20 turns. The word was 'ice-cream'.
#
# ====================
#   Starting Game 10/10
# ====================
#
# --- Validator secret word: phone ---
#
# --- Turn 1 ---
# Agent Question: Is the object alive?
# Validator Answer: no
# Agent Guess: machine
# Agent's guess was incorrect.
#
# --- Turn 2 ---
# Agent Question: Is the object man-made?
# Validator Answer: yes
# Agent Guess: car
# Agent's guess was incorrect.
#
# --- Turn 3 ---
# Agent Question: Is the object a tool?
# Validator Answer: yes
# Agent Guess: hammer
# Agent's guess was incorrect.
#
# --- Turn 4 ---
# Agent Question: Is the object a piece of furniture?
# Validator Answer: no
# Agent Guess: computer
# Agent's guess was incorrect.
#
# --- Turn 5 ---
# Agent Question: Is the object a piece of technology?
# Validator Answer: yes
# Agent Guess: phone
# Agent guessed correctly! The word was 'phone'.
#
# --- Evaluation Finished ---
# Final Score: 4 / 10 wins (40.00%)
